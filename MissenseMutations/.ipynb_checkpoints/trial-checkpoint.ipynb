# %%
import pandas as pd
import numpy as np
import os
from lxml import etree
import xml.etree.ElementTree as ET

# %%
aatranlation = {'Ala': 'A', 'Arg': 'R', 'Asn': 'N', 'Asp': 'D', 'Cys': 'C',
                'Glu': 'E', 'Gln': 'Q', 'Gly': 'G', 'His': 'H', 'Ile': 'I',
                'Leu': 'L', 'Lys': 'K', 'Met': 'M', 'Phe': 'F', 'Pro': 'P',
                'Ser': 'S', 'Thr': 'T', 'Trp': 'W', 'Tyr': 'Y', 'Val': 'V'}

# %%
def readHumanGenes(path):
    human_genes = []
    with open(path, 'r') as filehandle:
        human_genes = filehandle.read().splitlines()
    return human_genes

# %%
human_genes = readHumanGenes('../data/UniProtHumanEnzymeGenes.txt')

# %%
class variationHandler(object):
    def __init__(self, enzyme_genes):
        self.dictlist = {'interpretation': [], 'gene':[], 'gene_name':[], 'accession':[], 'mutation': [], 'NP': [], 'Chr': [], 'start':[], 'stop':[], 'referenceAllele':[], 'alternateAllele':[], 'FASTA':[], 'PDB': []}
        self.enzyme_genes = enzyme_genes
        self.gene = ""
        self.gene_name = ""
        self.interpretation = ""
        self.accession = ""
        self.mutation = ""
        self.np_num = ""
        self.change = ""
        self.chr = ""
        self.start_num = ""
        self.stop_num = ""
        self.referenceAllele = ""
        self.alternateAllele = ""
        self.is_GeneList = False
        self.ct_gene = 0
        self.check_grch = False
        self.ct_np = 0
        self.ct_mc = 0  # counter for Molecular Consequence tag
        self.is_haplotype = False  # check if a variation is haplotype or not
        self.is_missense = False
        self.is_conflicting = False
        self.is_not_provided = False
        self.is_interpretations = False
        self.is_interpretation = False
        self.is_description = False
        self.is_desc_hist = False
        self.intpn = []
        self.ct = 0
        self.ct_missense = 0
        self.ct_uncertain = 0
        self.ct_conflicting = 0
        self.ct_not_provided = 0
        
    def start(self, tag, attrs):
        if tag == 'VariationArchive':
            self.accession = attrs.get('Accession')
        elif tag == 'Haplotype':
            self.is_haplotype = True
        elif tag == 'GeneList':
            self.is_GeneList = True
        elif tag == 'Gene' and self.ct_gene == 0:
            self.gene = attrs.get('Symbol')
            self.gene_name = attrs.get('FullName')
            self.ct_gene += 1
        elif tag == 'SequenceLocation' and self.is_GeneList == False and self.check_grch == False:
            if attrs.get('Assembly') == 'GRCh38':
                self.chr = attrs.get('Chr')
                self.start_num = attrs.get('start')
                self.stop_num = attrs.get('stop')
                self.referenceAllele = attrs.get('referenceAlleleVCF')
                self.alternateAllele = attrs.get('alternateAlleleVCF')
                self.check_grch = True
        elif tag == 'ProteinExpression' and self.ct_np == 0:
            self.np_num = attrs.get('sequenceAccessionVersion')
            self.change = attrs.get('change') 
            if self.np_num and self.np_num.startswith('NP'):            
                self.ct_np += 1
        elif tag == 'MolecularConsequence' and self.ct_mc == 0:
            if attrs.get('Type') and 'missense' in attrs.get('Type').lower():
                self.is_missense = True
                self.ct_missense += 1
            self.ct_mc += 1
#         elif tag == 'RCVAccession':
#             self.interpretation = attrs.get('Interpretation').lower()
#             if "uncertain" in self.interpretation:
#                 self.is_uncertain = True
#                 self.ct_uncertain += 1
#             elif "conflicting" in self.interpretation:
#                 self.is_conflicting = True
#                 self.ct_conflicting += 1
#             elif "not provided" in self.interpretation:
#                 self.is_not_provided = True
#                 self.ct_not_provided += 1
        elif tag == 'Interpretations':
            self.is_interpretations = True
        elif tag == 'Interpretation':
            self.is_interpretation = True
        elif tag == 'Description':
            self.is_description = True
        elif tag == 'DescriptionHistory':
            self.is_desc_hist = True
            
    def end(self, tag):
        if tag == 'VariationArchive' or (self.is_haplotype and tag == 'SimpleAllele'):
            if (self.gene in self.enzyme_genes) and self.is_missense and (self.is_uncertain or self.is_conflicting or self.is_not_provided):
                try:
                    self.change = self.change.split('p.')[1]
                    before = aatranlation.get(self.change[0:3])
                    after = aatranlation.get(self.change[len(self.change) - 3:len(self.change)])
                except: 
                    before = None
                    after = None
                if before and after:  # check if both have a value in aa dict
                    num = self.change[3:len(self.change) - 3]
                    abbreviated_change = before + num + after
                    fasta = np.nan
                    self.dictlist['interpretation'].append(self.interpretation)
                    self.dictlist['gene'].append(self.gene)
                    self.dictlist['gene_name'].append(self.gene_name)
                    self.dictlist['accession'].append(self.accession)
                    self.dictlist['mutation'].append(abbreviated_change)
                    self.dictlist['NP'].append(self.np_num)
                    self.dictlist['Chr'].append(self.chr)
                    self.dictlist['start'].append(self.start_num)
                    self.dictlist['stop'].append(self.stop_num)
                    self.dictlist['referenceAllele'].append(self.referenceAllele)
                    self.dictlist['alternateAllele'].append(self.alternateAllele)
                    self.dictlist['FASTA'].append(fasta)
                    self.dictlist['PDB'].append(np.nan)
            if len(self.intpn) > 1:
                print(f'Interpretaion: {self.intpn}, Accession: {self.accession}, count: {self.ct}')
            if len(self.intpn) > 0 and 'conflicting' in self.intpn[0].lower():
                self.ct_conflicting += 1
#                print(f'Interpretaion: {self.intpn[0]}, Acdession: {self.accession}, count: {self.ct}')
            self.ct_gene = 0             
            self.check_grch = False
            self.is_missense = False
            self.is_uncertain = False
            self.is_conflicting = False
            self.is_not_provided = False
            self.ct_np = 0
            self.ct_mc = 0
            if tag == 'VariationArchive':
                self.ct +=1
                self.is_description = False
                if self.ct % 10000 == 0:
                    print(self.ct)
            self.intpn = []
        elif tag == 'GeneList':
            self.is_GeneList = False
        elif tag == 'Interpretations':
            self.is_interpretations = False
        elif tag == 'Interpretation':
            self.is_interpretaion = False
        elif tag == 'Description':
            self.is_description = False
        elif tag == 'DescriptionHistory':
            self.is_desc_hist = False
                
    def data(self, data):
        if self.is_interpretations and self.is_interpretation and self.is_description and (not self.is_desc_hist):
            self.intpn.append(data)
            
    def close(self):
        print(f"Variations: {self.ct}")
        print(f"Uncertain Significance: {self.ct_uncertain}")
        print(f"Conflicting Report: {self.ct_conflicting}")
        print(f"Missense: {self.ct_missense}")
        print('debug: the file is closed')
        return self.dictlist

# %%
# read xml file of variations from ClinVar
# return dataframe and write to a csv file
def readClinVarVariationsXML(input_path, output_path, gene_set):
    print('debug: start parcing')
    parser = etree.XMLParser(target=variationHandler(gene_set))
    data = etree.parse(input_path, parser)
    df = pd.DataFrame(data)
    df.to_csv(output_path, index = False, header = True)
    return df

# %%
xmlfile = '../data/ClinVarVariationRelease_00-latest_weekly.xml'
out_path = '../data/MM_enzyme.csv'
readClinVarVariationsXML(xmlfile, out_path, human_genes)
# Out:
# debug: start parcing
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300
        print(self.accession)
        
    def start(self, tag, attrs):
        if (tag == 'VariationArchive') and (attrs.get('Accession') == self.accession):
            self.is_accession = True
        if self.is_accession:
            print(f"{self.ct} tag: {tag}")
            self.ct += 1
            
    def end(self, tag):
        if self.is_accession:
            print(f"{self.ct} tag: /{tag}")
        if tag == 'VariationArchive':
            self.is_accession = False
            self.ct = 0
            if self.ct_all % 10000 == 0:
                print(self.ct_all)
            self.ct_all += 1
            
    def data(self, data):
        if self.is_accession and (data.strip()):
            print(f"    {self.ct} data: {data}")
            
    def close(self):
        print('debug: the xml file is closed')

# %%
# read xml file of variations from ClinVar
# return dataframe and write to a csv file
def readClinVarVariationsXMLSpecific(input_path, accession):
    print('debug: start parcing')
    parser = etree.XMLParser(target=variationHandlerSpecific(accession))
    data = etree.parse(input_path, parser)
    df = pd.DataFrame(data)
    return df

# %%
xmlfile = '../data/ClinVarVariationRelease_00-latest_weekly.xml'
accession = 'VCV000424711'
readClinVarVariationsXMLSpecific(xmlfile, accession)
# Out:
# debug: start parcing
# VCV000424711
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 0 tag: VariationArchive
# VCV000424711 and VCV000424711: True
# 1 tag: RecordStatus
# VCV000424711 and None: False
#     2 data: current
# 2 tag: /RecordStatus
# 2 tag: Species
# VCV000424711 and None: False
#     3 data: Homo sapiens
# 3 tag: /Species
# 3 tag: InterpretedRecord
# VCV000424711 and None: False
# 4 tag: Genotype
# VCV000424711 and None: False
# 5 tag: SimpleAllele
# VCV000424711 and None: False
# 6 tag: GeneList
# VCV000424711 and None: False
# 7 tag: Gene
# VCV000424711 and None: False
# 8 tag: Location
# VCV000424711 and None: False
# 9 tag: CytogeneticLocation
# VCV000424711 and None: False
#     10 data: 12q13.3
# 10 tag: /CytogeneticLocation
# 10 tag: SequenceLocation
# VCV000424711 and NC_000012.12: False
# 11 tag: /SequenceLocation
# 11 tag: SequenceLocation
# VCV000424711 and NC_000012.11: False
# 12 tag: /SequenceLocation
# 12 tag: /Location
# 12 tag: OMIM
# VCV000424711 and None: False
#     13 data: 156560
# 13 tag: /OMIM
# 13 tag: /Gene
# 13 tag: /GeneList
# 13 tag: Name
# VCV000424711 and None: False
#     14 data: NM_004990.4(MARS1):c.1031A
#     14 data: >
#     14 data: G (p.Tyr344Cys)
# 14 tag: /Name
# 14 tag: CanonicalSPDI
# VCV000424711 and None: False
#     15 data: NC_000012.12:57498562:A:G
# 15 tag: /CanonicalSPDI
# 15 tag: VariantType
# VCV000424711 and None: False
#     16 data: single nucleotide variant
# 16 tag: /VariantType
# 16 tag: Location
# VCV000424711 and None: False
# 17 tag: CytogeneticLocation
# VCV000424711 and None: False
#     18 data: 12q13.3
# 18 tag: /CytogeneticLocation
# 18 tag: SequenceLocation
# VCV000424711 and NC_000012.12: False
# 19 tag: /SequenceLocation
# 19 tag: SequenceLocation
# VCV000424711 and NC_000012.11: False
# 20 tag: /SequenceLocation
# 20 tag: /Location
# 20 tag: ProteinChange
# VCV000424711 and None: False
#     21 data: Y344C
# 21 tag: /ProteinChange
# 21 tag: HGVSlist
# VCV000424711 and None: False
# 22 tag: HGVS
# VCV000424711 and None: False
# 23 tag: NucleotideExpression
# VCV000424711 and None: False
# 24 tag: Expression
# VCV000424711 and None: False
#     25 data: NC_000012.11:g.57892346A
#     25 data: >
#     25 data: G
# 25 tag: /Expression
# 25 tag: /NucleotideExpression
# 25 tag: /HGVS
# 25 tag: HGVS
# VCV000424711 and None: False
# 26 tag: NucleotideExpression
# VCV000424711 and None: False
# 27 tag: Expression
# VCV000424711 and None: False
#     28 data: NC_000012.12:g.57498563A
#     28 data: >
#     28 data: G
# 28 tag: /Expression
# 28 tag: /NucleotideExpression
# 28 tag: /HGVS
# 28 tag: HGVS
# VCV000424711 and None: False
# 29 tag: NucleotideExpression
# VCV000424711 and None: False
# 30 tag: Expression
# VCV000424711 and None: False
#     31 data: NC_000012.11:g.57892346A
#     31 data: >
#     31 data: G
# 31 tag: /Expression
# 31 tag: /NucleotideExpression
# 31 tag: /HGVS
# 31 tag: HGVS
# VCV000424711 and None: False
# 32 tag: NucleotideExpression
# VCV000424711 and None: False
# 33 tag: Expression
# VCV000424711 and None: False
#     34 data: NM_004990.4:c.1031A
#     34 data: >
#     34 data: G
# 34 tag: /Expression
# 34 tag: /NucleotideExpression
# 34 tag: ProteinExpression
# VCV000424711 and None: False
# 35 tag: Expression
# VCV000424711 and None: False
#     36 data: NP_004981.2:p.Tyr344Cys
# 36 tag: /Expression
# 36 tag: /ProteinExpression
# 36 tag: MolecularConsequence
# VCV000424711 and None: False
# 37 tag: /MolecularConsequence
# 37 tag: /HGVS
# 37 tag: HGVS
# VCV000424711 and None: False
# 38 tag: NucleotideExpression
# VCV000424711 and None: False
# 39 tag: Expression
# VCV000424711 and None: False
#     40 data: NG_034077.1:g.15611A
#     40 data: >
#     40 data: G
# 40 tag: /Expression
# 40 tag: /NucleotideExpression
# 40 tag: /HGVS
# 40 tag: HGVS
# VCV000424711 and None: False
# 41 tag: ProteinExpression
# VCV000424711 and None: False
# 42 tag: Expression
# VCV000424711 and None: False
#     43 data: P56192:p.Tyr344Cys
# 43 tag: /Expression
# 43 tag: /ProteinExpression
# 43 tag: /HGVS
# 43 tag: /HGVSlist
# 43 tag: Interpretations
# VCV000424711 and None: False
# 44 tag: Interpretation
# VCV000424711 and None: False
# 45 tag: Description
# VCV000424711 and None: False
#     46 data: Pathogenic
# 46 tag: /Description
# 46 tag: Citation
# VCV000424711 and None: False
# 47 tag: ID
# VCV000424711 and None: False
#     48 data: 25913036
# 48 tag: /ID
# 48 tag: /Citation
# 48 tag: ConditionList
# VCV000424711 and None: False
# 49 tag: TraitSet
# VCV000424711 and None: False
# 50 tag: Trait
# VCV000424711 and None: False
# 51 tag: Name
# VCV000424711 and None: False
# 52 tag: ElementValue
# VCV000424711 and None: False
#     53 data: PULMONARY ALVEOLAR PROTEINOSIS, REUNION ISLAND
# 53 tag: /ElementValue
# 53 tag: XRef
# VCV000424711 and None: False
# 54 tag: /XRef
# 54 tag: /Name
# 54 tag: Name
# VCV000424711 and None: False
# 55 tag: ElementValue
# VCV000424711 and None: False
#     56 data: Interstitial lung and liver disease
# 56 tag: /ElementValue
# 56 tag: /Name
# 56 tag: Symbol
# VCV000424711 and None: False
# 57 tag: ElementValue
# VCV000424711 and None: False
#     58 data: ILLD
# 58 tag: /ElementValue
# 58 tag: XRef
# VCV000424711 and None: False
# 59 tag: /XRef
# 59 tag: /Symbol
# 59 tag: XRef
# VCV000424711 and None: False
# 60 tag: /XRef
# 60 tag: XRef
# VCV000424711 and None: False
# 61 tag: /XRef
# 61 tag: XRef
# VCV000424711 and None: False
# 62 tag: /XRef
# 62 tag: /Trait
# 62 tag: /TraitSet
# 62 tag: /ConditionList
# 62 tag: /Interpretation
# 62 tag: /Interpretations
# 62 tag: XRefList
# VCV000424711 and None: False
# 63 tag: XRef
# VCV000424711 and None: False
# 64 tag: /XRef
# 64 tag: XRef
# VCV000424711 and None: False
# 65 tag: /XRef
# 65 tag: XRef
# VCV000424711 and None: False
# 66 tag: /XRef
# 66 tag: XRef
# VCV000424711 and None: False
# 67 tag: /XRef
# 67 tag: XRef
# VCV000424711 and None: False
# 68 tag: /XRef
# 68 tag: /XRefList
# 68 tag: AlleleFrequencyList
# VCV000424711 and None: False
# 69 tag: AlleleFrequency
# VCV000424711 and None: False
# 70 tag: /AlleleFrequency
# 70 tag: AlleleFrequency
# VCV000424711 and None: False
# 71 tag: /AlleleFrequency
# 71 tag: /AlleleFrequencyList
# 71 tag: /SimpleAllele
# 71 tag: Haplotype
# VCV000424711 and None: False
# 72 tag: SimpleAllele
# VCV000424711 and None: False
# 73 tag: GeneList
# VCV000424711 and None: False
# 74 tag: Gene
# VCV000424711 and None: False
# 75 tag: Location
# VCV000424711 and None: False
# 76 tag: CytogeneticLocation
# VCV000424711 and None: False
#     77 data: 12q13.3
# 77 tag: /CytogeneticLocation
# 77 tag: SequenceLocation
# VCV000424711 and NC_000012.12: False
# 78 tag: /SequenceLocation
# 78 tag: SequenceLocation
# VCV000424711 and NC_000012.11: False
# 79 tag: /SequenceLocation
# 79 tag: /Location
# 79 tag: OMIM
# VCV000424711 and None: False
#     80 data: 156560
# 80 tag: /OMIM
# 80 tag: /Gene
# 80 tag: /GeneList
# 80 tag: Name
# VCV000424711 and None: False
#     81 data: NM_004990.4(MARS1):c.1700C
#     81 data: >
#     81 data: T (p.Ser567Leu)
# 81 tag: /Name
# 81 tag: CanonicalSPDI
# VCV000424711 and None: False
#     82 data: NC_000012.12:57512299:C:T
# 82 tag: /CanonicalSPDI
# 82 tag: VariantType
# VCV000424711 and None: False
#     83 data: single nucleotide variant
# 83 tag: /VariantType
# 83 tag: Location
# VCV000424711 and None: False
# 84 tag: CytogeneticLocation
# VCV000424711 and None: False
#     85 data: 12q13.3
# 85 tag: /CytogeneticLocation
# 85 tag: SequenceLocation
# VCV000424711 and NC_000012.12: False
# 86 tag: /SequenceLocation
# 86 tag: SequenceLocation
# VCV000424711 and NC_000012.11: False
# 87 tag: /SequenceLocation
# 87 tag: /Location
# 87 tag: ProteinChange
# VCV000424711 and None: False
#     88 data: S567L
# 88 tag: /ProteinChange
# 88 tag: HGVSlist
# VCV000424711 and None: False
# 89 tag: HGVS
# VCV000424711 and None: False
# 90 tag: NucleotideExpression
# VCV000424711 and None: False
# 91 tag: Expression
# VCV000424711 and None: False
#     92 data: NC_000012.11:g.57906083C
#     92 data: >
#     92 data: T
# 92 tag: /Expression
# 92 tag: /NucleotideExpression
# 92 tag: /HGVS
# 92 tag: HGVS
# VCV000424711 and None: False
# 93 tag: NucleotideExpression
# VCV000424711 and None: False
# 94 tag: Expression
# VCV000424711 and None: False
#     95 data: NC_000012.12:g.57512300C
#     95 data: >
#     95 data: T
# 95 tag: /Expression
# 95 tag: /NucleotideExpression
# 95 tag: /HGVS
# 95 tag: HGVS
# VCV000424711 and None: False
# 96 tag: NucleotideExpression
# VCV000424711 and None: False
# 97 tag: Expression
# VCV000424711 and None: False
#     98 data: NM_004990.4:c.1700C
#     98 data: >
#     98 data: T
# 98 tag: /Expression
# 98 tag: /NucleotideExpression
# 98 tag: ProteinExpression
# VCV000424711 and None: False
# 99 tag: Expression
# VCV000424711 and None: False
#     100 data: NP_004981.2:p.Ser567Leu
# 100 tag: /Expression
# 100 tag: /ProteinExpression
# 100 tag: MolecularConsequence
# VCV000424711 and None: False
# 101 tag: /MolecularConsequence
# 101 tag: /HGVS
# 101 tag: HGVS
# VCV000424711 and None: False
# 102 tag: NucleotideExpression
# VCV000424711 and None: False
# 103 tag: Expression
# VCV000424711 and None: False
#     104 data: NG_034077.1:g.29348C
#     104 data: >
#     104 data: T
# 104 tag: /Expression
# 104 tag: /NucleotideExpression
# 104 tag: /HGVS
# 104 tag: HGVS
# VCV000424711 and None: False
# 105 tag: ProteinExpression
# VCV000424711 and None: False
# 106 tag: Expression
# VCV000424711 and None: False
#     107 data: P56192:p.Ser567Leu
# 107 tag: /Expression
# 107 tag: /ProteinExpression
# 107 tag: /HGVS
# 107 tag: /HGVSlist
# 107 tag: Interpretations
# VCV000424711 and None: False
# 108 tag: Interpretation
# VCV000424711 and None: False
# 109 tag: Description
# VCV000424711 and None: False
#     110 data: no interpretation for the single variant
# 110 tag: /Description
# 110 tag: /Interpretation
# 110 tag: /Interpretations
# 110 tag: XRefList
# VCV000424711 and None: False
# 111 tag: XRef
# VCV000424711 and None: False
# 112 tag: /XRef
# 112 tag: XRef
# VCV000424711 and None: False
# 113 tag: /XRef
# 113 tag: XRef
# VCV000424711 and None: False
# 114 tag: /XRef
# 114 tag: XRef
# VCV000424711 and None: False
# 115 tag: /XRef
# 115 tag: XRef
# VCV000424711 and None: False
# 116 tag: /XRef
# 116 tag: /XRefList
# 116 tag: AlleleFrequencyList
# VCV000424711 and None: False
# 117 tag: AlleleFrequency
# VCV000424711 and None: False
# 118 tag: /AlleleFrequency
# 118 tag: AlleleFrequency
# VCV000424711 and None: False
# 119 tag: /AlleleFrequency
# 119 tag: AlleleFrequency
# VCV000424711 and None: False
# 120 tag: /AlleleFrequency
# 120 tag: AlleleFrequency
# VCV000424711 and None: False
# 121 tag: /AlleleFrequency
# 121 tag: AlleleFrequency
# VCV000424711 and None: False
# 122 tag: /AlleleFrequency
# 122 tag: /AlleleFrequencyList
# 122 tag: /SimpleAllele
# 122 tag: SimpleAllele
# VCV000424711 and None: False
# 123 tag: GeneList
# VCV000424711 and None: False
# 124 tag: Gene
# VCV000424711 and None: False
# 125 tag: Location
# VCV000424711 and None: False
# 126 tag: CytogeneticLocation
# VCV000424711 and None: False
#     127 data: 12q13.3
# 127 tag: /CytogeneticLocation
# 127 tag: SequenceLocation
# VCV000424711 and NC_000012.12: False
# 128 tag: /SequenceLocation
# 128 tag: SequenceLocation
# VCV000424711 and NC_000012.11: False
# 129 tag: /SequenceLocation
# 129 tag: /Location
# 129 tag: OMIM
# VCV000424711 and None: False
#     130 data: 156560
# 130 tag: /OMIM
# 130 tag: /Gene
# 130 tag: /GeneList
# 130 tag: Name
# VCV000424711 and None: False
#     131 data: NM_004990.4(MARS1):c.1177G
#     131 data: >
#     131 data: A (p.Ala393Thr)
# 131 tag: /Name
# 131 tag: CanonicalSPDI
# VCV000424711 and None: False
#     132 data: NC_000012.12:57500405:G:A
# 132 tag: /CanonicalSPDI
# 132 tag: VariantType
# VCV000424711 and None: False
#     133 data: single nucleotide variant
# 133 tag: /VariantType
# 133 tag: Location
# VCV000424711 and None: False
# 134 tag: CytogeneticLocation
# VCV000424711 and None: False
#     135 data: 12q13.3
# 135 tag: /CytogeneticLocation
# 135 tag: SequenceLocation
# VCV000424711 and NC_000012.12: False
# 136 tag: /SequenceLocation
# 136 tag: SequenceLocation
# VCV000424711 and NC_000012.11: False
# 137 tag: /SequenceLocation
# 137 tag: /Location
# 137 tag: ProteinChange
# VCV000424711 and None: False
#     138 data: A393T
# 138 tag: /ProteinChange
# 138 tag: HGVSlist
# VCV000424711 and None: False
# 139 tag: HGVS
# VCV000424711 and None: False
# 140 tag: NucleotideExpression
# VCV000424711 and None: False
# 141 tag: Expression
# VCV000424711 and None: False
#     142 data: NC_000012.12:g.57500406G
#     142 data: >
#     142 data: A
# 142 tag: /Expression
# 142 tag: /NucleotideExpression
# 142 tag: /HGVS
# 142 tag: HGVS
# VCV000424711 and None: False
# 143 tag: NucleotideExpression
# VCV000424711 and None: False
# 144 tag: Expression
# VCV000424711 and None: False
#     145 data: NC_000012.11:g.57894189G
#     145 data: >
#     145 data: A
# 145 tag: /Expression
# 145 tag: /NucleotideExpression
# 145 tag: /HGVS
# 145 tag: HGVS
# VCV000424711 and None: False
# 146 tag: NucleotideExpression
# VCV000424711 and None: False
# 147 tag: Expression
# VCV000424711 and None: False
#     148 data: NM_004990.4:c.1177G
#     148 data: >
#     148 data: A
# 148 tag: /Expression
# 148 tag: /NucleotideExpression
# 148 tag: ProteinExpression
# VCV000424711 and None: False
# 149 tag: Expression
# VCV000424711 and None: False
#     150 data: NP_004981.2:p.Ala393Thr
# 150 tag: /Expression
# 150 tag: /ProteinExpression
# 150 tag: MolecularConsequence
# VCV000424711 and None: False
# 151 tag: /MolecularConsequence
# 151 tag: /HGVS
# 151 tag: HGVS
# VCV000424711 and None: False
# 152 tag: NucleotideExpression
# VCV000424711 and None: False
# 153 tag: Expression
# VCV000424711 and None: False
#     154 data: NG_034077.1:g.17454G
#     154 data: >
#     154 data: A
# 154 tag: /Expression
# 154 tag: /NucleotideExpression
# 154 tag: /HGVS
# 154 tag: HGVS
# VCV000424711 and None: False
# 155 tag: ProteinExpression
# VCV000424711 and None: False
# 156 tag: Expression
# VCV000424711 and None: False
#     157 data: P56192:p.Ala393Thr
# 157 tag: /Expression
# 157 tag: /ProteinExpression
# 157 tag: /HGVS
# 157 tag: /HGVSlist
# 157 tag: Interpretations
# VCV000424711 and None: False
# 158 tag: Interpretation
# VCV000424711 and None: False
# 159 tag: Description
# VCV000424711 and None: False
#     160 data: no interpretation for the single variant
# 160 tag: /Description
# 160 tag: /Interpretation
# 160 tag: /Interpretations
# 160 tag: XRefList
# VCV000424711 and None: False
# 161 tag: XRef
# VCV000424711 and None: False
# 162 tag: /XRef
# 162 tag: XRef
# VCV000424711 and None: False
# 163 tag: /XRef
# 163 tag: XRef
# VCV000424711 and None: False
# 164 tag: /XRef
# 164 tag: XRef
# VCV000424711 and None: False
# 165 tag: /XRef
# 165 tag: XRef
# VCV000424711 and None: False
# 166 tag: /XRef
# 166 tag: /XRefList
# 166 tag: AlleleFrequencyList
# VCV000424711 and None: False
# 167 tag: AlleleFrequency
# VCV000424711 and None: False
# 168 tag: /AlleleFrequency
# 168 tag: AlleleFrequency
# VCV000424711 and None: False
# 169 tag: /AlleleFrequency
# 169 tag: AlleleFrequency
# VCV000424711 and None: False
# 170 tag: /AlleleFrequency
# 170 tag: AlleleFrequency
# VCV000424711 and None: False
# 171 tag: /AlleleFrequency
# 171 tag: AlleleFrequency
# VCV000424711 and None: False
# 172 tag: /AlleleFrequency
# 172 tag: AlleleFrequency
# VCV000424711 and None: False
# 173 tag: /AlleleFrequency
# 173 tag: /AlleleFrequencyList
# 173 tag: GlobalMinorAlleleFrequency
# VCV000424711 and None: False
# 174 tag: /GlobalMinorAlleleFrequency
# 174 tag: /SimpleAllele
# 174 tag: Name
# VCV000424711 and None: False
#     175 data: NM_004990.3(MARS):c.[1700C
#     175 data: >
#     175 data: T;1177G
#     175 data: >
#     175 data: A]
# 175 tag: /Name
# 175 tag: VariationType
# VCV000424711 and None: False
#     176 data: Haplotype
# 176 tag: /VariationType
# 176 tag: OtherNameList
# VCV000424711 and None: False
# 177 tag: Name
# VCV000424711 and None: False
#     178 data: MARS, SER567LEU (rs143592405) AND ALA393THR (rs141340466)
# 178 tag: /Name
# 178 tag: /OtherNameList
# 178 tag: HGVSlist
# VCV000424711 and None: False
# 179 tag: HGVS
# VCV000424711 and None: False
# 180 tag: NucleotideExpression
# VCV000424711 and None: False
# 181 tag: Expression
# VCV000424711 and None: False
#     182 data: NC_000012.11:g.[57906083C
#     182 data: >
#     182 data: T;57894189G
#     182 data: >
#     182 data: A]
# 182 tag: /Expression
# 182 tag: /NucleotideExpression
# 182 tag: /HGVS
# 182 tag: HGVS
# VCV000424711 and None: False
# 183 tag: NucleotideExpression
# VCV000424711 and None: False
# 184 tag: Expression
# VCV000424711 and None: False
#     185 data: NM_004990.3:c.[1700C
#     185 data: >
#     185 data: T;1177G
#     185 data: >
#     185 data: A]
# 185 tag: /Expression
# 185 tag: /NucleotideExpression
# 185 tag: /HGVS
# 185 tag: HGVS
# VCV000424711 and None: False
# 186 tag: NucleotideExpression
# VCV000424711 and None: False
# 187 tag: Expression
# VCV000424711 and None: False
#     188 data: NG_034077.1:g.[29348C
#     188 data: >
#     188 data: T;17454G
#     188 data: >
#     188 data: A]
# 188 tag: /Expression
# 188 tag: /NucleotideExpression
# 188 tag: /HGVS
# 188 tag: /HGVSlist
# 188 tag: Interpretations
# VCV000424711 and None: False
# 189 tag: Interpretation
# VCV000424711 and None: False
# 190 tag: Description
# VCV000424711 and None: False
#     191 data: Pathogenic
# 191 tag: /Description
# 191 tag: Citation
# VCV000424711 and None: False
# 192 tag: ID
# VCV000424711 and None: False
#     193 data: 25913036
# 193 tag: /ID
# 193 tag: /Citation
# 193 tag: ConditionList
# VCV000424711 and None: False
# 194 tag: TraitSet
# VCV000424711 and None: False
# 195 tag: Trait
# VCV000424711 and None: False
# 196 tag: Name
# VCV000424711 and None: False
# 197 tag: ElementValue
# VCV000424711 and None: False
#     198 data: Pulmonary alveolar proteinosis
# 198 tag: /ElementValue
# 198 tag: XRef
# VCV000424711 and None: False
# 199 tag: /XRef
# 199 tag: /Name
# 199 tag: Name
# VCV000424711 and None: False
# 200 tag: ElementValue
# VCV000424711 and None: False
#     201 data: infantile pulmonary alveolar proteinosis
# 201 tag: /ElementValue
# 201 tag: /Name
# 201 tag: Name
# VCV000424711 and None: False
# 202 tag: ElementValue
# VCV000424711 and None: False
#     203 data: familial interstitial lung disease
# 203 tag: /ElementValue
# 203 tag: /Name
# 203 tag: Name
# VCV000424711 and None: False
# 204 tag: ElementValue
# VCV000424711 and None: False
#     205 data: pneumonitis
# 205 tag: /ElementValue
# 205 tag: /Name
# 205 tag: Name
# VCV000424711 and None: False
# 206 tag: ElementValue
# VCV000424711 and None: False
#     207 data: Alveolar proteinosis
# 207 tag: /ElementValue
# 207 tag: XRef
# VCV000424711 and None: False
# 208 tag: /XRef
# 208 tag: /Name
# 208 tag: Symbol
# VCV000424711 and None: False
# 209 tag: ElementValue
# VCV000424711 and None: False
#     210 data: PAP
# 210 tag: /ElementValue
# 210 tag: /Symbol
# 210 tag: XRef
# VCV000424711 and None: False
# 211 tag: /XRef
# 211 tag: XRef
# VCV000424711 and None: False
# 212 tag: /XRef
# 212 tag: /Trait
# 212 tag: /TraitSet
# 212 tag: TraitSet
# VCV000424711 and None: False
# 213 tag: Trait
# VCV000424711 and None: False
# 214 tag: Name
# VCV000424711 and None: False
# 215 tag: ElementValue
# VCV000424711 and None: False
#     216 data: PULMONARY ALVEOLAR PROTEINOSIS, REUNION ISLAND
# 216 tag: /ElementValue
# 216 tag: XRef
# VCV000424711 and None: False
# 217 tag: /XRef
# 217 tag: /Name
# 217 tag: Name
# VCV000424711 and None: False
# 218 tag: ElementValue
# VCV000424711 and None: False
#     219 data: Interstitial lung and liver disease
# 219 tag: /ElementValue
# 219 tag: /Name
# 219 tag: Symbol
# VCV000424711 and None: False
# 220 tag: ElementValue
# VCV000424711 and None: False
#     221 data: ILLD
# 221 tag: /ElementValue
# 221 tag: XRef
# VCV000424711 and None: False
# 222 tag: /XRef
# 222 tag: /Symbol
# 222 tag: XRef
# VCV000424711 and None: False
# 223 tag: /XRef
# 223 tag: XRef
# VCV000424711 and None: False
# 224 tag: /XRef
# 224 tag: XRef
# VCV000424711 and None: False
# 225 tag: /XRef
# 225 tag: /Trait
# 225 tag: /TraitSet
# 225 tag: /ConditionList
# 225 tag: /Interpretation
# 225 tag: /Interpretations
# 225 tag: XRefList
# VCV000424711 and None: False
# 226 tag: XRef
# VCV000424711 and None: False
# 227 tag: /XRef
# 227 tag: XRef
# VCV000424711 and None: False
# 228 tag: /XRef
# 228 tag: XRef
# VCV000424711 and None: False
# 229 tag: /XRef
# 229 tag: /XRefList
# 229 tag: /Haplotype
# 229 tag: Name
# VCV000424711 and None: False
#     230 data: NM_004990.3(MARS1):c.[1031A
#     230 data: >
#     230 data: G];[1177G
#     230 data: >
#     230 data: A[1700C
#     230 data: >
#     230 data: T]
# 230 tag: /Name
# 230 tag: VariationType
# VCV000424711 and None: False
#     231 data: CompoundHeterozygote
# 231 tag: /VariationType
# 231 tag: HGVSlist
# VCV000424711 and None: False
# 232 tag: HGVS
# VCV000424711 and None: False
# 233 tag: NucleotideExpression
# VCV000424711 and None: False
# 234 tag: Expression
# VCV000424711 and None: False
#     235 data: NM_004990.3:c.[1031A
#     235 data: >
#     235 data: G];[1177G
#     235 data: >
#     235 data: A[1700C
#     235 data: >
#     235 data: T]
# 235 tag: /Expression
# 235 tag: /NucleotideExpression
# 235 tag: /HGVS
# 235 tag: /HGVSlist
# 235 tag: /Genotype
# 235 tag: ReviewStatus
# VCV000424711 and None: False
#     236 data: no assertion criteria provided
# 236 tag: /ReviewStatus
# 236 tag: RCVList
# VCV000424711 and None: False
# 237 tag: RCVAccession
# VCV000424711 and RCV000169767: False
# 238 tag: InterpretedConditionList
# VCV000424711 and None: False
# 239 tag: InterpretedCondition
# VCV000424711 and None: False
#     240 data: Pulmonary alveolar proteinosis
# 240 tag: /InterpretedCondition
# 240 tag: /InterpretedConditionList
# 240 tag: /RCVAccession
# 240 tag: /RCVList
# 240 tag: Interpretations
# VCV000424711 and None: False
# 241 tag: Interpretation
# VCV000424711 and None: False
# 242 tag: Description
# VCV000424711 and None: False
#     243 data: Pathogenic
# 243 tag: /Description
# 243 tag: Citation
# VCV000424711 and None: False
# 244 tag: ID
# VCV000424711 and None: False
#     245 data: 25913036
# 245 tag: /ID
# 245 tag: /Citation
# 245 tag: ConditionList
# VCV000424711 and None: False
# 246 tag: TraitSet
# VCV000424711 and None: False
# 247 tag: Trait
# VCV000424711 and None: False
# 248 tag: Name
# VCV000424711 and None: False
# 249 tag: ElementValue
# VCV000424711 and None: False
#     250 data: Pulmonary alveolar proteinosis
# 250 tag: /ElementValue
# 250 tag: XRef
# VCV000424711 and None: False
# 251 tag: /XRef
# 251 tag: /Name
# 251 tag: Name
# VCV000424711 and None: False
# 252 tag: ElementValue
# VCV000424711 and None: False
#     253 data: infantile pulmonary alveolar proteinosis
# 253 tag: /ElementValue
# 253 tag: /Name
# 253 tag: Name
# VCV000424711 and None: False
# 254 tag: ElementValue
# VCV000424711 and None: False
#     255 data: familial interstitial lung disease
# 255 tag: /ElementValue
# 255 tag: /Name
# 255 tag: Name
# VCV000424711 and None: False
# 256 tag: ElementValue
# VCV000424711 and None: False
#     257 data: pneumonitis
# 257 tag: /ElementValue
# 257 tag: /Name
# 257 tag: Name
# VCV000424711 and None: False
# 258 tag: ElementValue
# VCV000424711 and None: False
#     259 data: Alveolar proteinosis
# 259 tag: /ElementValue
# 259 tag: XRef
# VCV000424711 and None: False
# 260 tag: /XRef
# 260 tag: /Name
# 260 tag: Symbol
# VCV000424711 and None: False
# 261 tag: ElementValue
# VCV000424711 and None: False
#     262 data: PAP
# 262 tag: /ElementValue
# 262 tag: /Symbol
# 262 tag: XRef
# VCV000424711 and None: False
# 263 tag: /XRef
# 263 tag: XRef
# VCV000424711 and None: False
# 264 tag: /XRef
# 264 tag: /Trait
# 264 tag: /TraitSet
# 264 tag: /ConditionList
# 264 tag: /Interpretation
# 264 tag: /Interpretations
# 264 tag: ClinicalAssertionList
# VCV000424711 and None: False
# 265 tag: ClinicalAssertion
# VCV000424711 and None: False
# 266 tag: ClinVarSubmissionID
# VCV000424711 and None: False
# 267 tag: /ClinVarSubmissionID
# 267 tag: ClinVarAccession
# VCV000424711 and SCV000196710: False
# 268 tag: /ClinVarAccession
# 268 tag: RecordStatus
# VCV000424711 and None: False
#     269 data: current
# 269 tag: /RecordStatus
# 269 tag: ReviewStatus
# VCV000424711 and None: False
#     270 data: no assertion criteria provided
# 270 tag: /ReviewStatus
# 270 tag: Interpretation
# VCV000424711 and None: False
# 271 tag: Description
# VCV000424711 and None: False
#     272 data: Pathogenic
# 272 tag: /Description
# 272 tag: /Interpretation
# 272 tag: Assertion
# VCV000424711 and None: False
#     273 data: variation to disease
# 273 tag: /Assertion
# 273 tag: ObservedInList
# VCV000424711 and None: False
# 274 tag: ObservedIn
# VCV000424711 and None: False
# 275 tag: Sample
# VCV000424711 and None: False
# 276 tag: Origin
# VCV000424711 and None: False
#     277 data: germline
# 277 tag: /Origin
# 277 tag: GeographicOrigin
# VCV000424711 and None: False
#     278 data: Reunion;France
# 278 tag: /GeographicOrigin
# 278 tag: Tissue
# VCV000424711 and None: False
#     279 data: blood
# 279 tag: /Tissue
# 279 tag: Species
# VCV000424711 and None: False
#     280 data: human
# 280 tag: /Species
# 280 tag: AffectedStatus
# VCV000424711 and None: False
#     281 data: yes
# 281 tag: /AffectedStatus
# 281 tag: NumberTested
# VCV000424711 and None: False
#     282 data: 1
# 282 tag: /NumberTested
# 282 tag: Gender
# VCV000424711 and None: False
#     283 data: male
# 283 tag: /Gender
# 283 tag: /Sample
# 283 tag: Method
# VCV000424711 and None: False
# 284 tag: MethodType
# VCV000424711 and None: False
#     285 data: research
# 285 tag: /MethodType
# 285 tag: /Method
# 285 tag: ObservedData
# VCV000424711 and None: False
# 286 tag: Attribute
# VCV000424711 and None: False
# 287 tag: /Attribute
# 287 tag: /ObservedData
# 287 tag: /ObservedIn
# 287 tag: /ObservedInList
# 287 tag: Genotype
# VCV000424711 and None: False
# 288 tag: Haplotype
# VCV000424711 and None: False
# 289 tag: SimpleAllele
# VCV000424711 and None: False
# 290 tag: GeneList
# VCV000424711 and None: False
# 291 tag: Gene
# VCV000424711 and None: False
# 292 tag: /Gene
# 292 tag: /GeneList
# 292 tag: VariantType
# VCV000424711 and None: False
#     293 data: Variation
# 293 tag: /VariantType
# 293 tag: AttributeSet
# VCV000424711 and None: False
# 294 tag: Attribute
# VCV000424711 and None: False
#     295 data: NC_000012.11:g.57906083C
#     295 data: >
#     295 data: T
# 295 tag: /Attribute
# 295 tag: /AttributeSet
# 295 tag: /SimpleAllele
# 295 tag: SimpleAllele
# VCV000424711 and None: False
# 296 tag: GeneList
# VCV000424711 and None: False
# 297 tag: Gene
# VCV000424711 and None: False
# 298 tag: /Gene
# 298 tag: /GeneList
# 298 tag: VariantType
# VCV000424711 and None: False
#     299 data: Variation
# 299 tag: /VariantType
# 299 tag: AttributeSet
# VCV000424711 and None: False
# 300 tag: Attribute
# VCV000424711 and None: False
#     301 data: NC_000012.11:g.57894189G
#     301 data: >
#     301 data: A
# 301 tag: /Attribute
# 301 tag: /AttributeSet
# 301 tag: /SimpleAllele
# 301 tag: AttributeSet
# VCV000424711 and None: False
# 302 tag: Attribute
# VCV000424711 and None: False
#     303 data: NC_000012.11:g.[57906083C
#     303 data: >
#     303 data: T;57894189G
#     303 data: >
#     303 data: A]
# 303 tag: /Attribute
# 303 tag: /AttributeSet
# 303 tag: /Haplotype
# 303 tag: SimpleAllele
# VCV000424711 and None: False
# 304 tag: GeneList
# VCV000424711 and None: False
# 305 tag: Gene
# VCV000424711 and None: False
# 306 tag: /Gene
# 306 tag: /GeneList
# 306 tag: VariantType
# VCV000424711 and None: False
#     307 data: Variation
# 307 tag: /VariantType
# 307 tag: AttributeSet
# VCV000424711 and None: False
# 308 tag: Attribute
# VCV000424711 and None: False
#     309 data: NC_000012.11:g.57892346A
#     309 data: >
#     309 data: G
# 309 tag: /Attribute
# 309 tag: /AttributeSet
# 309 tag: /SimpleAllele
# 309 tag: VariationType
# VCV000424711 and None: False
#     310 data: CompoundHeterozygote
# 310 tag: /VariationType
# 310 tag: /Genotype
# 310 tag: TraitSet
# VCV000424711 and None: False
# 311 tag: Trait
# VCV000424711 and None: False
# 312 tag: Name
# VCV000424711 and None: False
# 313 tag: ElementValue
# VCV000424711 and None: False
#     314 data: Pulmonary alveolar proteinosis
# 314 tag: /ElementValue
# 314 tag: /Name
# 314 tag: XRef
# VCV000424711 and None: False
# 315 tag: /XRef
# 315 tag: /Trait
# 315 tag: /TraitSet
# 315 tag: SubmissionNameList
# VCV000424711 and None: False
# 316 tag: SubmissionName
# VCV000424711 and None: False
#     317 data: MARS_mutations_in_PAP
# 317 tag: /SubmissionName
# 317 tag: /SubmissionNameList
# 317 tag: /ClinicalAssertion
# 317 tag: /ClinicalAssertionList
# 317 tag: TraitMappingList
# VCV000424711 and None: False
# 318 tag: TraitMapping
# VCV000424711 and None: False
# 319 tag: MedGen
# VCV000424711 and None: False
# 320 tag: /MedGen
# 320 tag: /TraitMapping
# 320 tag: /TraitMappingList
# 320 tag: /InterpretedRecord
# 320 tag: /VariationArchive
# 530000
# debug: the xml file is closed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-3b05d92ccf27> in <module>()
#       1 xmlfile = '../data/ClinVarVariationRelease_00-latest_weekly.xml'
#       2 accession = 'VCV000424711'
# ----> 3 readClinVarVariationsXMLSpecific(xmlfile, accession)
#
# <ipython-input-65-328029511227> in readClinVarVariationsXMLSpecific(input_path, accession)
#       4     print('debug: start parcing')
#       5     parser = etree.XMLParser(target=variationHandlerSpecific(accession))
# ----> 6     data = etree.parse(input_path, parser)
#       7     df = pd.DataFrame(data)
#       8     return df
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResultDoc()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResultDoc()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStart()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# <ipython-input-64-826d9709f8a5> in start(self, tag, attrs)
#      10         if (tag == 'VariationArchive') and (attrs.get('Accession') == self.accession):
#      11             self.is_accession = True
# ---> 12         if self.is_accession:
#      13             print(f"{self.ct} tag: {tag}")
#      14             self.ct += 1
#
# KeyboardInterrupt:

# %%
tree = etree.parse('../data/clinvarVariation_7.xml')
root = tree.getroot()
node = tree.find('VariationArchive[@Accession="VCV000012722"]')
mydata = etree.tostring(node)
myfile = open('../data/subnode.xml', 'wb')
myfile.write(mydata)
# Out:
# 42977

# %%
# makes dictionary of fasta sequences and np number 
# returns the dictionary
def makeDictOfFasta(dictpath):
    fasta_dict = {}
    for root, d_names, file_names in os.walk(dictpath):
        for filename in file_names:
            fname = os.path.join(root, filename)
            with open(fname) as f:
                print('opened a fasta file')
                np_num = ''
                sequence = ''
                for line in f:
                    if line[0] == '>':
                        if sequence != '':
                            fasta_dict[np_num] = sequence
                            np_num = ''
                            sequence = ''                    
                        i = 1
                        while line[i] != ' ':
                            np_num += line[i]
                            i += 1
                    else:
                        line = line.strip('\n')
                        sequence += line
    print(f'length of fasta dictionary: {len(fasta_dict)}')
    return fasta_dict

# %%
df_0 = pd.read_csv('../data/MM_enzyme.csv')
df_0.head()
# Out:
#            interpretation   gene  \
# 0  uncertain significance  HOGA1
# 1  uncertain significance    AGA
# 2  uncertain significance   DPYD
# 3  uncertain significance    PTS
# 4  uncertain significance   PROC
#
#                                            gene_name     accession mutation  \
# 0                4-hydroxy-2-oxoglutarate aldolase 1  VCV000000031     R97C
# 1                            aspartylglucosaminidase  VCV000000222     G60D
# 2                    dihydropyrimidine dehydrogenase  VCV000000437    R886H
# 3                6-pyruvoyltetrahydropterin synthase  VCV000000477     R16C
# 4  protein C, inactivator of coagulation factors ...  VCV000000661    P210L
#
#             NP Chr      start       stop referenceAllele alternateAllele  \
# 0  NP_612422.2  10   97598852   97598852               C               T
# 1  NP_000018.2   4  177440375  177440375               C               T
# 2  NP_000101.2   1   97098598   97098598               C               T
# 3  NP_000308.1  11  112226489  112226489               C               T
# 4  NP_000303.1   2  127426178  127426178               C               T
#
#                    FASTA  PDB
# 0  SERLEVVSRVRQAMPKNRLLL  NaN
# 1  GGSALDAVESGCAMCEREQCD  NaN
# 2  LPSFGPYLEQRKKIIAENKIR  NaN
# 3  GGRRCQAQVSRRISFSASHRL  NaN
# 4  DTEDQEDQVDPRLIDGKMTRR  NaN

# %%
fasta_dict = makeDictOfFasta('../fasta_sequences/')
# Out:
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# length of fasta dictionary: 113602

# %%
# crops fasta sequence
# returns the cropped sequnece with a specified range
def cropFASTA(sequence, location, reference, seqRange):
    if location - 1 < len(sequence) and sequence[location - 1] == reference:
        proteinSeq = sequence[0 if location - 1 - seqRange <= 0 else location - 1 - seqRange : location + seqRange]
        return proteinSeq
    else:
        return None

# %%
def addFASTAfromDict(fasta_dict, df):
    none_acc = []
    seq_list = []
    for index, row in df.iterrows():
        mutation = row['mutation']
        try:
            ref = mutation[0]
            location = int(mutation[1:len(mutation)-1])
            np_num = row['NP']  # specify the column of np 
            sequence = fasta_dict.get(np_num)
            seqRange = 10  # range of sequences to take
            seq = cropFASTA(sequence, location, ref, seqRange) if sequence else None
        except:
            seq = None
            accession = row['accession']
            none_acc.append(accession)
        seq_list.append(seq)
    df['FASTA'] = seq_list
    print(f'Unfound Sequences: {len(none_acc)} {none_acc}')
    return df

# %%
df_1 = addFASTAfromDict(fasta_dict, df_0)
df_1.head()
# Out:
# Unfound Sequences: 38 ['VCV000181879', 'VCV000288381', 'VCV000418418', 'VCV000428273', 'VCV000474413', 'VCV000484704', 'VCV000490097', 'VCV000503859', 'VCV000531064', 'VCV000541685', 'VCV000582159', 'VCV000583086', 'VCV000589537', 'VCV000591262', 'VCV000591672', 'VCV000591831', 'VCV000594518', 'VCV000598475', 'VCV000524323', 'VCV000437115', 'VCV000216871', 'VCV000418344', 'VCV000464734', 'VCV000481269', 'VCV000566152', 'VCV000800863', 'VCV000462579', 'VCV000537105', 'VCV000572650', 'VCV000625941', 'VCV000630885', 'VCV000650338', 'VCV000650666', 'VCV000658054', 'VCV000664737', 'VCV000240738', 'VCV000411042', 'VCV000412448']
#            interpretation   gene  \
# 0  uncertain significance  HOGA1
# 1  uncertain significance    AGA
# 2  uncertain significance   DPYD
# 3  uncertain significance    PTS
# 4  uncertain significance   PROC
#
#                                            gene_name     accession mutation  \
# 0                4-hydroxy-2-oxoglutarate aldolase 1  VCV000000031     R97C
# 1                            aspartylglucosaminidase  VCV000000222     G60D
# 2                    dihydropyrimidine dehydrogenase  VCV000000437    R886H
# 3                6-pyruvoyltetrahydropterin synthase  VCV000000477     R16C
# 4  protein C, inactivator of coagulation factors ...  VCV000000661    P210L
#
#             NP Chr      start       stop referenceAllele alternateAllele  \
# 0  NP_612422.2  10   97598852   97598852               C               T
# 1  NP_000018.2   4  177440375  177440375               C               T
# 2  NP_000101.2   1   97098598   97098598               C               T
# 3  NP_000308.1  11  112226489  112226489               C               T
# 4  NP_000303.1   2  127426178  127426178               C               T
#
#                    FASTA  PDB
# 0  SERLEVVSRVRQAMPKNRLLL  NaN
# 1  GGSALDAVESGCAMCEREQCD  NaN
# 2  LPSFGPYLEQRKKIIAENKIR  NaN
# 3  GGRRCQAQVSRRISFSASHRL  NaN
# 4  DTEDQEDQVDPRLIDGKMTRR  NaN

# %%
df_1[['NP', 'gene', 'gene_name', 'FASTA']].head()
# Out:
#             NP   gene                                          gene_name  \
# 0  NP_612422.2  HOGA1                4-hydroxy-2-oxoglutarate aldolase 1
# 1  NP_000018.2    AGA                            aspartylglucosaminidase
# 2  NP_000101.2   DPYD                    dihydropyrimidine dehydrogenase
# 3  NP_000308.1    PTS                6-pyruvoyltetrahydropterin synthase
# 4  NP_000303.1   PROC  protein C, inactivator of coagulation factors ...
#
#                    FASTA
# 0  SERLEVVSRVRQAMPKNRLLL
# 1  GGSALDAVESGCAMCEREQCD
# 2  LPSFGPYLEQRKKIIAENKIR
# 3  GGRRCQAQVSRRISFSASHRL
# 4  DTEDQEDQVDPRLIDGKMTRR

# %%
def makeFASTAfile(df, output_path):
    subset = df[['NP', 'gene', 'gene_name', 'FASTA']]
    tuples = [tuple(x) for x in subset.values]
    with open(output_path, 'w') as f:
        for tup in tuples:
            line = '>' + '\t'.join(tup[0:3]) + '\n'
            fasta = str(tup[3]) + '\n'
            f.write(line)
            f.write(fasta)

# %%
makeFASTAfile(df_1, '../data/fasta.txt')
