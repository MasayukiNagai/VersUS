# %%
import pandas as pd
import numpy as np
import os
from lxml import etree
import xml.etree.ElementTree as ET

# %%
aatranlation = {'Ala': 'A', 'Arg': 'R', 'Asn': 'N', 'Asp': 'D', 'Cys': 'C',
                'Glu': 'E', 'Gln': 'Q', 'Gly': 'G', 'His': 'H', 'Ile': 'I',
                'Leu': 'L', 'Lys': 'K', 'Met': 'M', 'Phe': 'F', 'Pro': 'P',
                'Ser': 'S', 'Thr': 'T', 'Trp': 'W', 'Tyr': 'Y', 'Val': 'V'}

# %%
def readHumanGenes(path):
    human_genes = []
    with open(path, 'r') as filehandle:
        human_genes = filehandle.read().splitlines()
    return human_genes

# %%
human_genes = readHumanGenes('../data/UniProtHumanEnzymeGenes.txt')
print(human_genes)
# Out:
# ['CAMKMT', 'CSNK2A3', 'CPA6', 'AGA', 'CTDSPL', 'CERS5', 'CERS6', 'CDKAL1', 'CYP46A1', 'CYP4A11', 'ADH1B', 'ATP2A1', 'ATP10D', 'CDK5', 'B4GALT4', 'CDK6', 'CDC42', 'ADAM8', 'ARSA', 'CDK7', 'ASAH2', 'ADAMTS3', 'NT5C2', 'ATP11C', 'CTSB', 'CDK8', 'ADAMTS19', 'ATP10B', 'CHPF2', 'AFG1L', 'ADAMTS20', 'ATXN3L', 'ATP23', 'CDKL1', 'ACAD8', 'CDKL3', 'ATP2B2', 'CDKL4', 'ACVR1C', 'ACVRL1', 'C1R', 'ADH4', 'ACY1', 'ACOX1', 'ADAM28', 'B3GNTL1', 'RNPEP', 'ADTRP', 'ALKBH5', 'CDK9', 'ALG12', 'PRSS22', 'ALDH4A1', 'CNOT8', 'ATP10A', 'CYP7A1', 'ADH7', 'ALG1L', 'CAPN9', 'ASAH1', 'CTH', 'AAK1', 'ACLY', 'NT5C3A', 'APOBEC3F', 'ALG2', 'ATP11A', 'ATP11B', 'ALDH7A1', 'ABCD1', 'ARSB', 'ATG10', 'ADO', 'NT5E', 'ATP12A', 'ATXN3', 'GLB1', 'SMPDL3B', 'PRMT2', 'CASP4', 'BLVRA', 'CTSC', 'CDKN3', 'AADAT', 'ANPEP', 'AICDA', 'CASP10', 'ARIH1', 'BAAT', 'CDO1', 'CYP2D7', 'CHAC2', 'ALDH3B1', 'ADH6', 'BCO1', 'BCDIN3D', 'APOBEC3B', 'NT5C1B', 'BST1', 'BCO2', 'ALG1', 'B4GALT3', 'CNP', 'APOBEC3D', 'ADH1C', 'ABHD15', 'B4GALT7', 'ANKIB1', 'ATP2A3', 'ACE2', 'PRMT1', 'ASMTL', 'GOT1', 'ATP13A1', 'ABCG1', 'ATP13A2', 'ACE', 'ACADVL', 'ADA', 'ACSL3', 'BMP2K', 'ACSL5', 'BDH2', 'ACSM2B', 'ACOT6', 'ARMT1', 'ADAMTS5', 'ATG4D', 'ATP1A2', 'CHSY1', 'BAZ1B', 'ALG10', 'BMX', 'CDK2', 'CS', 'CDK4', 'ACADSB', 'APOBEC3A', 'ADH1A', 'CP', 'ADAMTS1', 'NT5C1A', 'SPATA5', 'APOBEC3C', 'ACSBG1', 'ACACA', 'ADAM9', 'AOX1', 'GOT1L1', 'SMPDL3A', 'CDKL2', 'PRMT3', 'ADAT1', 'ADAM10', 'CDC7', 'TNK2', 'SMPD1', 'ACVR1', 'ALDH2', 'ABHD12B', 'ASRGL1', 'ACSBG2', 'ATP2C1', 'AOC2', 'CERK', 'CERS1', 'CERS3', 'ALG13', 'BARD1', 'CNOT7', 'CERS4', 'CYP7B1', 'CDK3', 'CYP8B1', 'CAPN8', 'CASP2', 'CYP4A22', 'BLVRB', 'CHPT1', 'AFG3L2', 'RBBP8', 'NT5C3B', 'CASP3', 'APOBEC3G', 'B4GALT6', 'ACACB', 'ATP2A2', 'ADAMTS4', 'ALDH8A1', 'LAP3', 'ATG3', 'ACAD9', 'ACADM', 'CASP5', 'AEN', 'CDK11B', 'ADPRHL1', 'ACVR1B', 'ABHD2', 'PGLS', 'ACSS1', 'ETNPPL', 'A4GNT', 'A4GALT', 'ACSS3', 'BMPR1B', 'ADCY6', 'ATF2', 'CPA2', 'CASK', 'CPT1A', 'CMPK2', 'CLYBL', 'CEL', 'AKR1E2', 'CMBL', 'AGPS', 'AACS', 'CAT', 'BBOX1', 'ASPA', 'B3GNT3', 'ACOT7L', 'APTX', 'ARAF', 'ADAMTS13', 'ADAMTS2', 'ATG4C', 'ATP8B1', 'DDX17', 'FRRS1', 'DYRK1A', 'GFOD1', 'DTX2', 'CA13', 'BRCA1', 'AGMO', 'BIRC2', 'CYP3A5', 'CDK20', 'CERS2', 'ACADL', 'ASMT', 'ADAT2', 'ADAM15', 'PRKAA2', 'ACSM2A', 'BMPR1A', 'B3GNT2', 'AKT3', 'AKR7A2', 'B4GALNT1', 'B4GALT5', 'AGBL3', 'ALDOB', 'ANKK1', 'BCKDK', 'PRMT5', 'PGD', 'CYB561D2', 'CASP9', 'CTSF', 'ATM', 'CASP1', 'B3GNT5', 'ACER3', 'ATAT1', 'ABHD14A', 'AQR', 'AOC3', 'ATL3', 'CAPN1', 'CAPN7', 'ACOT12', 'AMHR2', 'HSPD1', 'STUB1', 'CTDP1', 'AKR1C8P', 'CNOT6', 'ACADS', 'CASP8', 'APRT', 'ADAM21', 'APEX1', 'AKR7L', 'AMPD1', 'ADAMTS18', 'C1RL', 'DPH2', 'DTX4', 'AGTPBP1', 'CHST11', 'CFB', 'CTDSP1', 'CYP3A7', 'CYP39A1', 'ANTKMT', 'ABCG2', 'GOT2', 'CASD1', 'ADH5', 'ACSM1', 'ACSM4', 'AIFM1', 'APOBEC1', 'APOBEC4', 'ATR', 'GUSB', 'C1S', 'ACHE', 'FMO3', 'COP1', 'ALDH1A1', 'ARSK', 'ALDH3A2', 'ADAMTS6', 'CASP6', 'CASP7', 'ACR', 'ACSL1', 'ADPRHL2', 'ADGRV1', 'AASS', 'ADCK2', 'ASNA1', 'ACSM5', 'AADACL4', 'AIFM2', 'HAAO', 'RAD54L2', 'ATG4B', 'B3GAT1', 'B3GALNT1', 'AOAH', 'ACOT11', 'DUSP14', 'PPT1', 'SUOX', 'TRMT11', 'TBK1', 'TRIM6', 'TRIM7', 'SLFN14', 'SHPK', 'ACAA1', 'TPP1', 'SDS', 'AHCYL2', 'TKFC', 'TMPRSS3', 'TGS1', 'ERVK-10', 'UMPS', 'TYMP', 'ZRANB3', 'TYMS', 'XDH', 'UFL1', 'UPP1', 'ERVK-21', 'USP17L13', 'TTBK2', 'TYSND1', 'XPNPEP2', 'TSTD1', 'TSSK1B', 'YME1L1', 'WWP1', 'NUDT12', 'OTUD3', 'SUV39H1', 'ULK1', 'TSSK2', 'ZDHHC11B', 'SMARCA4', 'ERVK-25', 'ZNRF2', 'ZNRF4', 'SIRT3', 'XYLT1', 'USP21', 'UBASH3B', 'USP37', 'USP10', 'UGT1A8', 'ULK2', 'CARS2', 'ST8SIA6', 'QARS', 'SGPP2', 'TMPRSS6', 'USP25', 'UCK2', 'TSSK3', 'HERV-K104', 'TTF2', 'TTBK1', 'USP17L19', 'ZC3H12A', 'TYRP1', 'ZSWIM2', 'UHRF2', 'UGT1A6', 'UGT2B10', 'ULK4', 'WRN', 'VAT1L', 'XPNPEP3', 'VAT1', 'USP17L15', 'ZDHHC3', 'TTLL6', 'TPH1', 'ST6GALNAC5', 'SMARCA1', 'SETD7', 'UBE2L3', 'UBE2H', 'USP17L6P', 'VNN1', 'NUGGC', 'SRC', 'UBE4A', 'ZDHHC4', 'TTLL4', 'ZDHHC9', 'UGT1A3', 'UGT3A2', 'SGMS2', 'USP40', 'USP17L ...

# %%
class variationHandler(object):
    def __init__(self, enzyme_genes):
        self.dictlist = {'interpretation': [], 'gene':[], 'gene_name':[], 'accession':[], 'mutation': [], 'NP': [], 'Chr': [], 'start':[], 'stop':[], 'referenceAllele':[], 'alternateAllele':[]}
        self.enzyme_genes = enzyme_genes
        self.gene = ""
        self.gene_name = ""
        self.accession = ""
        self.mutation = ""
        self.np_num = ""
        self.change = ""
        self.chr = ""
        self.start_num = ""
        self.stop_num = ""
        self.referenceAllele = ""
        self.alternateAllele = ""
        self.is_GeneList = False
        self.ct_gene = 0
        self.check_grch = False
        self.ct_np = 0
        self.ct_mc = 0  # counter for Molecular Consequence tag
        self.is_haplotype = False  # check if a variation is haplotype or not
        self.is_missense = False
        self.is_conflicting = False
        self.is_not_provided = False
        self.is_interpretations = False
        self.is_interpretation = False
        self.is_description = False
        self.is_desc_hist = False
        self.intpn = []
        self.ct = 0
        self.ct_missense = 0
        self.ct_uncertain = 0
        self.ct_conflicting = 0
        self.ct_not_provided = 0
        
    def start(self, tag, attrs):
        if tag == 'VariationArchive':
            self.accession = attrs.get('Accession')
        elif tag == 'Haplotype':
            self.is_haplotype = True
        elif tag == 'GeneList':
            self.is_GeneList = True
        elif tag == 'Gene' and self.ct_gene == 0:
            self.gene = attrs.get('Symbol')
            self.gene_name = attrs.get('FullName')
            self.ct_gene += 1
        elif tag == 'SequenceLocation' and self.is_GeneList == False and self.check_grch == False:
            if attrs.get('Assembly') == 'GRCh38':
                self.chr = attrs.get('Chr')
                self.start_num = attrs.get('start')
                self.stop_num = attrs.get('stop')
                self.referenceAllele = attrs.get('referenceAlleleVCF')
                self.alternateAllele = attrs.get('alternateAlleleVCF')
                self.check_grch = True
        elif tag == 'ProteinExpression' and self.ct_np == 0:
            self.np_num = attrs.get('sequenceAccessionVersion')
            self.change = attrs.get('change') 
            if self.np_num and self.np_num.startswith('NP'):            
                self.ct_np += 1
        elif tag == 'MolecularConsequence' and self.ct_mc == 0:
            if attrs.get('Type') and 'missense' in attrs.get('Type').lower():
                self.is_missense = True
                self.ct_missense += 1
            self.ct_mc += 1
        elif tag == 'Interpretations':
            self.is_interpretations = True
        elif tag == 'Interpretation':
            self.is_interpretation = True
        elif tag == 'Description':
            self.is_description = True
        elif tag == 'DescriptionHistory':
            self.is_desc_hist = True
            
    def end(self, tag):
        if (tag == 'VariationArchive') or (self.is_haplotype and tag == 'SimpleAllele'):
        
            if len(self.intpn) == 1:
                interpretation = self.intpn[0].lower()
                if "uncertain" in interpretation:
                    self.is_uncertain = True
                    self.ct_uncertain += 1
                elif "conflicting" in interpretation:
                    self.is_conflicting = True
                    self.ct_conflicting += 1
                elif "not provided" in interpretation:
                    self.is_not_provided = True
                    self.ct_not_provided += 1
            elif len(self.intpn) > 1:
                print(f'Interpretaion: {self.intpn}, Accession: {self.accession}, count: {self.ct}')
            
            if (self.gene in self.enzyme_genes) and self.is_missense and (self.is_uncertain or self.is_conflicting or self.is_not_provided):
                try:
                    self.change = self.change.split('p.')[1]
                    before = aatranlation.get(self.change[0:3])
                    after = aatranlation.get(self.change[len(self.change) - 3:len(self.change)])
                except: 
                    before = None
                    after = None
                if before and after:  # check if both have a value in aa dict
                    num = self.change[3:len(self.change) - 3]
                    abbreviated_change = before + num + after
                    fasta = np.nan
                    self.dictlist['interpretation'].append(interpretation)
                    self.dictlist['gene'].append(self.gene)
                    self.dictlist['gene_name'].append(self.gene_name)
                    self.dictlist['accession'].append(self.accession)
                    self.dictlist['mutation'].append(abbreviated_change)
                    self.dictlist['NP'].append(self.np_num)
                    self.dictlist['Chr'].append(self.chr)
                    self.dictlist['start'].append(self.start_num)
                    self.dictlist['stop'].append(self.stop_num)
                    self.dictlist['referenceAllele'].append(self.referenceAllele)
                    self.dictlist['alternateAllele'].append(self.alternateAllele)
            self.is_haplotype = False
            self.ct_gene = 0             
            self.check_grch = False
            self.is_missense = False
            self.is_uncertain = False
            self.is_conflicting = False
            self.is_not_provided = False
            self.ct_np = 0
            self.ct_mc = 0
            self.intpn = []
            if tag == 'VariationArchive':
                self.ct +=1
                if self.ct % 10000 == 0:
                    print(f'counter: {self.ct}')
        elif tag == 'GeneList':
            self.is_GeneList = False
        elif tag == 'Interpretations':
            self.is_interpretations = False
        elif tag == 'Interpretation':
            self.is_interpretaion = False
        elif tag == 'Description':
            self.is_description = False
        elif tag == 'DescriptionHistory':
            self.is_desc_hist = False
                
    def data(self, data):
        if self.is_interpretations and self.is_interpretation and self.is_description and (not self.is_desc_hist):
            self.intpn.append(data)
            
    def close(self):
        print(f"Variations: {self.ct}")
        print(f"Uncertain Significance: {self.ct_uncertain}")
        print(f"Conflicting Report: {self.ct_conflicting}")
        print(f"Not Provided: {self.ct_not_provided}")
        print(f"Missense: {self.ct_missense}")
        print('debug: the file is closed')
        return self.dictlist

# %%
# read xml file of variations from ClinVar
# return dataframe and write to a csv file
def readClinVarVariationsXML(input_path, output_path, gene_set):
    print('debug: start parcing')
    parser = etree.XMLParser(target=variationHandler(gene_set))
    data = etree.parse(input_path, parser)
    df = pd.DataFrame(data)
    df.to_csv(output_path, index = False, header = True)
    return df

# %%
xmlfile = '../data/ClinVarVariationRelease_00-latest_weekly.xml'
out_path = '../data/MM_enzyme.csv'
df_0 = readClinVarVariationsXML(xmlfile, out_path, human_genes)
df_0.head()
# Out:
# debug: start parcing
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000001981, count: 9424
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000003667, count: 9968
# counter: 10000
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000004368, count: 10192
# Interpretaion: ['Benign', 'Pathogenic'], Accession: VCV000005706, count: 10611
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic, protective, risk factor'], Accession: VCV000008152, count: 11352
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000008241, count: 11384
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000008596, count: 11517
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000011158, count: 12432
# Interpretaion: ['Likely benign', 'Pathogenic'], Accession: VCV000011906, count: 12644
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000012173, count: 12712
# Interpretaion: ['Likely benign, other', 'drug response'], Accession: VCV000012722, count: 12862
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000012809, count: 12898
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000013621, count: 13154
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000014382, count: 13396
# Interpretaion: ['Uncertain significance', 'Pathogenic'], Accession: VCV000014535, count: 13409
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000014913, count: 13608
# Interpretaion: ['no interpretation for the single variant', 'other'], Accession: VCV000015762, count: 14134
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000016565, count: 14462
# Interpretaion: ['no interpretation for the single variant', 'other'], Accession: VCV000016887, count: 14589
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000024977, count: 15952
# Interpretaion: ['Pathogenic', 'Pathogenic'], Accession: VCV000025042, count: 15989
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000025511, count: 16218
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant', 'Pathogenic'], Accession: VCV000031662, count: 16911
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000051008, count: 19063
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000055809, count: 19081
# counter: 20000
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000065392, count: 21145
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant', 'Pathogenic'], Accession: VCV000065613, count: 21210
# Interpretaion: ['Likely pathogenic', 'Pathogenic', 'Pathogenic'], Accession: VCV000101229, count: 26310
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000132775, count: 27809
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000132776, count: 27810
# counter: 30000
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000180222, count: 37513
# Interpretaion: ['no interpretation for the single variant', 'Likely pathogenic'], Accession: VCV000190221, count: 39062
# Interpretaion: ['Pathogenic', 'Pathogenic'], Accession: VCV000190352, count: 39112
# counter: 40000
# Interpretaion: ['Pathogenic', 'Pathogenic'], Accession: VCV000203434, count: 43996
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000204202, count: 44302
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000204293, count: 44366
# Interpretaion: ['no interpretation for the single variant', 'Likely pathogenic'], Accession: VCV000217348, count: 47382
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000224506, count: 48817
# Interpretaion: ['Pathogenic', 'Pathogenic'], Accession: VCV000235817, count: 49517
# Interpretaion: ['Pathogenic', 'Pathogenic'], Accession: VCV000235818, count: 49518
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000236230, count: 49608
# counter: 50000
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242384, count: 50634
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242385, count: 50635
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242419, count: 50638
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242420, count: 50639
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242421, count: 50640
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242425, count: 50643
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242427, count: 50644
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242431, count: 50646
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242432, count: 50647
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242433, count: 50648
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242435, count: 50650
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242436, count: 50651
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242439, count: 50652
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242440, count: 50653
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242474, count: 50655
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242475, count: 50656
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242476, count: 50657
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242486, count: 50658
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242487, count: 50659
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242492, count: 50660
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242504, count: 50661
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242512, count: 50662
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242514, count: 50663
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242522, count: 50664
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242525, count: 50665
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242526, count: 50666
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242533, count: 50667
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242534, count: 50668
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242571, count: 50669
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242574, count: 50670
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242575, count: 50671
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242590, count: 50672
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242591, count: 50673
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242609, count: 50674
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242618, count: 50675
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242619, count: 50676
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242636, count: 50677
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242637, count: 50678
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242638, count: 50679
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242639, count: 50680
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242652, count: 50683
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242653, count: 50684
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242654, count: 50685
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242667, count: 50686
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242668, count: 50687
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242669, count: 50688
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242670, count: 50689
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242673, count: 50690
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242674, count: 50691
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242688, count: 50692
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242705, count: 50693
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242709, count: 50694
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242714, count: 50695
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242715, count: 50696
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242717, count: 50697
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242718, count: 50698
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242720, count: 50699
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242723, count: 50701
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242726, count: 50702
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242730, count: 50704
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242732, count: 50705
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242738, count: 50706
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242760, count: 50708
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242761, count: 50709
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242776, count: 50710
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242782, count: 50711
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242785, count: 50713
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242789, count: 50714
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242792, count: 50715
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242794, count: 50717
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242798, count: 50718
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242799, count: 50719
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242801, count: 50720
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242809, count: 50721
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242813, count: 50722
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000242820, count: 50723
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000242987, count: 50758
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000253111, count: 51511
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264658, count: 55788
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264659, count: 55789
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264660, count: 55790
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264668, count: 55791
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264669, count: 55792
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264672, count: 55793
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000264675, count: 55794
# Interpretaion: ['no interpretation for the single variant', 'Uncertain significance'], Accession: VCV000266012, count: 56248
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267283, count: 56300
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267284, count: 56301
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267287, count: 56303
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267288, count: 56304
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267289, count: 56305
# Interpretaion: ['no interpretation for the single variant', 'Pathogenic'], Accession: VCV000267491, count: 56338
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267742, count: 56340
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000267743, count: 56341
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000279614, count: 56439
# Interpretaion: ['no interpretation for the single variant', 'no interpretation for the single variant'], Accession: VCV000279615, count: 56440
# counter: 60000
# counter: 70000
# Variations: 77671
# Uncertain Significance: 32358
# Conflicting Report: 1497
# Not Provided: 5289
# Missense: 28805
# debug: the file is closed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6eedabb7184a> in <module>()
#       1 xmlfile = '../data/ClinVarVariationRelease_00-latest_weekly.xml'
#       2 out_path = '../data/MM_enzyme2.csv'
# ----> 3 df_0 = readClinVarVariationsXML(xmlfile, out_path, human_genes)
#       4 df_0.head()
#
# <ipython-input-10-f8860ac34705> in readClinVarVariationsXML(input_path, output_path, gene_set)
#       4     print('debug: start parcing')
#       5     parser = etree.XMLParser(target=variationHandler(gene_set))
# ----> 6     data = etree.parse(input_path, parser)
#       7     df = pd.DataFrame(data)
#       8     df.to_csv(output_path, index = False, header = True)
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResultDoc()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResultDoc()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxEnd()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxEnd()
#
# <ipython-input-5-919a0ddb9d18> in end(self, tag)
#     125             self.intpn = []
#     126             if tag == 'VariationArchive':
# --> 127                 self.ct +=1
#     128                 if self.ct % 10000 == 0:
#     129                     print(f'counter: {self.ct}')
#
# KeyboardInterrupt:

# %%
class variationHandlerSpecific(object):
    def __init__(self, accession):
        self.is_accession = False
        self.accession = accession
        self.ct = 0
        self.ct_all = 0
        print(self.accession)
        
    def start(self, tag, attrs):
        if (tag == 'VariationArchive') and (attrs.get('Accession') == self.accession):
            self.is_accession = True
        if self.is_accession:
            print(f"{self.ct} tag: {tag}")
            self.ct += 1
            
    def end(self, tag):
        if self.is_accession:
            print(f"{self.ct} tag: /{tag}")
        if tag == 'VariationArchive':
            self.is_accession = False
            self.ct = 0
            if self.ct_all % 10000 == 0:
                print(self.ct_all)
            self.ct_all += 1
            
    def data(self, data):
        if self.is_accession and (data.strip()):
            print(f"    {self.ct} data: {data}")
            
    def close(self):
        print('debug: the xml file is closed')

# %%
# read xml file of variations from ClinVar
# return dataframe and write to a csv file
def readClinVarVariationsXMLSpecific(input_path, accession):
    print('debug: start parcing')
    parser = etree.XMLParser(target=variationHandlerSpecific(accession))
    data = etree.parse(input_path, parser)
    df = pd.DataFrame(data)
    return df

# %%
xmlfile = '../data/ClinVarVariationRelease_00-latest_weekly.xml'
accession = 'VCV000549768'
readClinVarVariationsXMLSpecific(xmlfile, accession)
# Out:
# debug: start parcing
# VCV000549768
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 0 tag: VariationArchive
# 1 tag: RecordStatus
#     2 data: current
# 2 tag: /RecordStatus
# 2 tag: Species
#     3 data: Homo sapiens
# 3 tag: /Species
# 3 tag: InterpretedRecord
# 4 tag: Genotype
# 5 tag: SimpleAllele
# 6 tag: GeneList
# 7 tag: Gene
# 8 tag: Location
# 9 tag: CytogeneticLocation
#     10 data: 10q11.21
# 10 tag: /CytogeneticLocation
# 10 tag: SequenceLocation
# 11 tag: /SequenceLocation
# 11 tag: SequenceLocation
# 12 tag: /SequenceLocation
# 12 tag: /Location
# 12 tag: OMIM
#     13 data: 164761
# 13 tag: /OMIM
# 13 tag: Haploinsufficiency
#     14 data: Sufficient evidence for dosage pathogenicity
# 14 tag: /Haploinsufficiency
# 14 tag: Triplosensitivity
#     15 data: No evidence available
# 15 tag: /Triplosensitivity
# 15 tag: Property
#     16 data: gene_acmg_incidental_2013
# 16 tag: /Property
# 16 tag: /Gene
# 16 tag: /GeneList
# 16 tag: Name
#     17 data: NM_020975.6(RET):c.1901G
#     17 data: >
#     17 data: A (p.Cys634Tyr)
# 17 tag: /Name
# 17 tag: CanonicalSPDI
#     18 data: NC_000010.11:43114500:G:A
# 18 tag: /CanonicalSPDI
# 18 tag: VariantType
#     19 data: single nucleotide variant
# 19 tag: /VariantType
# 19 tag: Location
# 20 tag: CytogeneticLocation
#     21 data: 10q11.21
# 21 tag: /CytogeneticLocation
# 21 tag: SequenceLocation
# 22 tag: /SequenceLocation
# 22 tag: SequenceLocation
# 23 tag: /SequenceLocation
# 23 tag: /Location
# 23 tag: OtherNameList
# 24 tag: Name
#     25 data: p.C634Y:TGC
#     25 data: >
#     25 data: TAC
# 25 tag: /Name
# 25 tag: /OtherNameList
# 25 tag: ProteinChange
#     26 data: C634Y
# 26 tag: /ProteinChange
# 26 tag: ProteinChange
#     27 data: C380Y
# 27 tag: /ProteinChange
# 27 tag: HGVSlist
# 28 tag: HGVS
# 29 tag: NucleotideExpression
# 30 tag: Expression
#     31 data: NC_000010.10:g.43609949G
#     31 data: >
#     31 data: A
# 31 tag: /Expression
# 31 tag: /NucleotideExpression
# 31 tag: /HGVS
# 31 tag: HGVS
# 32 tag: NucleotideExpression
# 33 tag: Expression
#     34 data: NC_000010.11:g.43114501G
#     34 data: >
#     34 data: A
# 34 tag: /Expression
# 34 tag: /NucleotideExpression
# 34 tag: /HGVS
# 34 tag: HGVS
# 35 tag: NucleotideExpression
# 36 tag: Expression
#     37 data: NM_001355216.1:c.1139G
#     37 data: >
#     37 data: A
# 37 tag: /Expression
# 37 tag: /NucleotideExpression
# 37 tag: ProteinExpression
# 38 tag: Expression
#     39 data: NP_001342145.1:p.Cys380Tyr
# 39 tag: /Expression
# 39 tag: /ProteinExpression
# 39 tag: MolecularConsequence
# 40 tag: /MolecularConsequence
# 40 tag: /HGVS
# 40 tag: HGVS
# 41 tag: NucleotideExpression
# 42 tag: Expression
#     43 data: NM_020630.5:c.1901G
#     43 data: >
#     43 data: A
# 43 tag: /Expression
# 43 tag: /NucleotideExpression
# 43 tag: ProteinExpression
# 44 tag: Expression
#     45 data: NP_065681.1:p.Cys634Tyr
# 45 tag: /Expression
# 45 tag: /ProteinExpression
# 45 tag: MolecularConsequence
# 46 tag: /MolecularConsequence
# 46 tag: /HGVS
# 46 tag: HGVS
# 47 tag: NucleotideExpression
# 48 tag: Expression
#     49 data: NM_020975.6:c.1901G
#     49 data: >
#     49 data: A
# 49 tag: /Expression
# 49 tag: /NucleotideExpression
# 49 tag: ProteinExpression
# 50 tag: Expression
#     51 data: NP_066124.1:p.Cys634Tyr
# 51 tag: /Expression
# 51 tag: /ProteinExpression
# 51 tag: MolecularConsequence
# 52 tag: /MolecularConsequence
# 52 tag: /HGVS
# 52 tag: HGVS
# 53 tag: NucleotideExpression
# 54 tag: Expression
#     55 data: LRG_518t1:c.1901G
#     55 data: >
#     55 data: A
# 55 tag: /Expression
# 55 tag: /NucleotideExpression
# 55 tag: ProteinExpression
# 56 tag: Expression
#     57 data: LRG_518p1:p.Cys634Tyr
# 57 tag: /Expression
# 57 tag: /ProteinExpression
# 57 tag: /HGVS
# 57 tag: HGVS
# 58 tag: NucleotideExpression
# 59 tag: Expression
#     60 data: LRG_518t2:c.1901G
#     60 data: >
#     60 data: A
# 60 tag: /Expression
# 60 tag: /NucleotideExpression
# 60 tag: /HGVS
# 60 tag: HGVS
# 61 tag: NucleotideExpression
# 62 tag: Expression
#     63 data: LRG_518t1:c.1901G
#     63 data: >
#     63 data: A
# 63 tag: /Expression
# 63 tag: /NucleotideExpression
# 63 tag: /HGVS
# 63 tag: HGVS
# 64 tag: NucleotideExpression
# 65 tag: Expression
#     66 data: NG_007489.1:g.42433G
#     66 data: >
#     66 data: A
# 66 tag: /Expression
# 66 tag: /NucleotideExpression
# 66 tag: /HGVS
# 66 tag: HGVS
# 67 tag: NucleotideExpression
# 68 tag: Expression
#     69 data: LRG_518:g.42433G
#     69 data: >
#     69 data: A
# 69 tag: /Expression
# 69 tag: /NucleotideExpression
# 69 tag: /HGVS
# 69 tag: HGVS
# 70 tag: ProteinExpression
# 71 tag: Expression
#     72 data: P07949:p.Cys634Tyr
# 72 tag: /Expression
# 72 tag: /ProteinExpression
# 72 tag: /HGVS
# 72 tag: /HGVSlist
# 72 tag: Interpretations
# 73 tag: Interpretation
# 74 tag: Description
#     75 data: Pathogenic
# 75 tag: /Description
# 75 tag: Citation
# 76 tag: ID
#     77 data: 3078962
# 77 tag: /ID
# 77 tag: /Citation
# 77 tag: Citation
# 78 tag: ID
#     79 data: 7907913
# 79 tag: /ID
# 79 tag: /Citation
# 79 tag: Citation
# 80 tag: ID
#     81 data: 9699127
# 81 tag: /ID
# 81 tag: /Citation
# 81 tag: Citation
# 82 tag: ID
#     83 data: 7491519
# 83 tag: /ID
# 83 tag: /Citation
# 83 tag: Citation
# 84 tag: ID
#     85 data: 28469506
# 85 tag: /ID
# 85 tag: /Citation
# 85 tag: Citation
# 86 tag: ID
#     87 data: 8099202
# 87 tag: /ID
# 87 tag: /Citation
# 87 tag: Citation
# 88 tag: ID
#     89 data: 9820617
# 89 tag: /ID
# 89 tag: /Citation
# 89 tag: Citation
# 90 tag: ID
#     91 data: 2008030
# 91 tag: /ID
# 91 tag: /Citation
# 91 tag: Citation
# 92 tag: ID
#     93 data: 19240193
# 93 tag: /ID
# 93 tag: /Citation
# 93 tag: Citation
# 94 tag: ID
#     95 data: 7860065
# 95 tag: /ID
# 95 tag: /Citation
# 95 tag: Citation
# 96 tag: ID
#     97 data: 20080836
# 97 tag: /ID
# 97 tag: /Citation
# 97 tag: Citation
# 98 tag: ID
#     99 data: 11524247
# 99 tag: /ID
# 99 tag: /Citation
# 99 tag: Citation
# 100 tag: ID
#     101 data: 7881414
# 101 tag: /ID
# 101 tag: /Citation
# 101 tag: Citation
# 102 tag: ID
#     103 data: 24716929
# 103 tag: /ID
# 103 tag: /Citation
# 103 tag: Citation
# 104 tag: ID
#     105 data: 21765987
# 105 tag: /ID
# 105 tag: /Citation
# 105 tag: Citation
# 106 tag: ID
#     107 data: 8570194
# 107 tag: /ID
# 107 tag: /Citation
# 107 tag: Citation
# 108 tag: ID
#     109 data: 29197744
# 109 tag: /ID
# 109 tag: /Citation
# 109 tag: Citation
# 110 tag: ID
#     111 data: 25157968
# 111 tag: /ID
# 111 tag: /Citation
# 111 tag: Citation
# 112 tag: ID
#     113 data: 7824936
# 113 tag: /ID
# 113 tag: /Citation
# 113 tag: Citation
# 114 tag: ID
#     115 data: 21655256
# 115 tag: /ID
# 115 tag: /Citation
# 115 tag: Citation
# 116 tag: ID
#     117 data: 27539324
# 117 tag: /ID
# 117 tag: /Citation
# 117 tag: Citation
# 118 tag: ID
#     119 data: 12686527
# 119 tag: /ID
# 119 tag: /Citation
# 119 tag: Citation
# 120 tag: ID
#     121 data: 12711285
# 121 tag: /ID
# 121 tag: /Citation
# 121 tag: Citation
# 122 tag: ID
#     123 data: 7915165
# 123 tag: /ID
# 123 tag: /Citation
# 123 tag: Citation
# 124 tag: ID
#     125 data: 9067749
# 125 tag: /ID
# 125 tag: /Citation
# 125 tag: Citation
# 126 tag: ID
#     127 data: 16099853
# 127 tag: /ID
# 127 tag: /Citation
# 127 tag: Citation
# 128 tag: ID
#     129 data: 29133048
# 129 tag: /ID
# 129 tag: /Citation
# 129 tag: Citation
# 130 tag: ID
#     131 data: 25810047
# 131 tag: /ID
# 131 tag: /Citation
# 131 tag: Citation
# 132 tag: ID
#     133 data: 23723040
# 133 tag: /ID
# 133 tag: /Citation
# 133 tag: Citation
# 134 tag: ID
#     135 data: 12864791
# 135 tag: /ID
# 135 tag: /Citation
# 135 tag: Citation
# 136 tag: ID
#     137 data: 9950371
# 137 tag: /ID
# 137 tag: /Citation
# 137 tag: Citation
# 138 tag: ID
#     139 data: 7914213
# 139 tag: /ID
# 139 tag: /Citation
# 139 tag: Citation
# 140 tag: ID
#     141 data: 9230192
# 141 tag: /ID
# 141 tag: /Citation
# 141 tag: Citation
# 142 tag: ID
#     143 data: 16868135
# 143 tag: /ID
# 143 tag: /Citation
# 143 tag: Citation
# 144 tag: ID
#     145 data: 19469690
# 145 tag: /ID
# 145 tag: /Citation
# 145 tag: Citation
# 146 tag: ID
#     147 data: 12746565
# 147 tag: /ID
# 147 tag: /Citation
# 147 tag: Citation
# 148 tag: ID
#     149 data: 7835899
# 149 tag: /ID
# 149 tag: /Citation
# 149 tag: Citation
# 150 tag: ID
#     151 data: 12604374
# 151 tag: /ID
# 151 tag: /Citation
# 151 tag: Citation
# 152 tag: URL
#     153 data: http://docm.genome.wustl.edu/variants/ENST00000355710:c.1901G
#     153 data: >
#     153 data: A
# 153 tag: /URL
# 153 tag: /Citation
# 153 tag: Citation
# 154 tag: ID
#     155 data: 18063059
# 155 tag: /ID
# 155 tag: /Citation
# 155 tag: Citation
# 156 tag: ID
#     157 data: 19062722
# 157 tag: /ID
# 157 tag: /Citation
# 157 tag: Citation
# 158 tag: URL
#     159 data: http://docm.genome.wustl.edu/variants/ENST00000340058:c.1901G
#     159 data: >
#     159 data: A
# 159 tag: /URL
# 159 tag: /Citation
# 159 tag: Citation
# 160 tag: ID
#     161 data: 12000816
# 161 tag: /ID
# 161 tag: /Citation
# 161 tag: DescriptionHistory
# 162 tag: Description
#     163 data: Pathogenic/Likely pathogenic
# 163 tag: /Description
# 163 tag: /DescriptionHistory
# 163 tag: DescriptionHistory
# 164 tag: Description
#     165 data: Pathogenic
# 165 tag: /Description
# 165 tag: /DescriptionHistory
# 165 tag: ConditionList
# 166 tag: TraitSet
# 167 tag: Trait
# 168 tag: Name
# 169 tag: ElementValue
#     170 data: Neoplasm
# 170 tag: /ElementValue
# 170 tag: XRef
# 171 tag: /XRef
# 171 tag: XRef
# 172 tag: /XRef
# 172 tag: /Name
# 172 tag: Name
# 173 tag: ElementValue
#     174 data: Neoplasia
# 174 tag: /ElementValue
# 174 tag: XRef
# 175 tag: /XRef
# 175 tag: /Name
# 175 tag: Name
# 176 tag: ElementValue
#     177 data: Oncological abnormality
# 177 tag: /ElementValue
# 177 tag: XRef
# 178 tag: /XRef
# 178 tag: /Name
# 178 tag: Name
# 179 tag: ElementValue
#     180 data: Oncology
# 180 tag: /ElementValue
# 180 tag: XRef
# 181 tag: /XRef
# 181 tag: /Name
# 181 tag: Name
# 182 tag: ElementValue
#     183 data: Tumor
# 183 tag: /ElementValue
# 183 tag: XRef
# 184 tag: /XRef
# 184 tag: /Name
# 184 tag: Name
# 185 tag: ElementValue
#     186 data: Tumour
# 186 tag: /ElementValue
# 186 tag: XRef
# 187 tag: /XRef
# 187 tag: /Name
# 187 tag: AttributeSet
# 188 tag: Attribute
#     189 data: neoplasm
# 189 tag: /Attribute
# 189 tag: /AttributeSet
# 189 tag: Citation
# 190 tag: ID
#     191 data: 22918138
# 191 tag: /ID
# 191 tag: /Citation
# 191 tag: Citation
# 192 tag: ID
#     193 data: 23619274
# 193 tag: /ID
# 193 tag: /Citation
# 193 tag: XRef
# 194 tag: /XRef
# 194 tag: XRef
# 195 tag: /XRef
# 195 tag: XRef
# 196 tag: /XRef
# 196 tag: XRef
# 197 tag: /XRef
# 197 tag: XRef
# 198 tag: /XRef
# 198 tag: /Trait
# 198 tag: /TraitSet
# 198 tag: TraitSet
# 199 tag: Trait
# 200 tag: Name
# 201 tag: ElementValue
#     202 data: Medullary thyroid carcinoma
# 202 tag: /ElementValue
# 202 tag: XRef
# 203 tag: /XRef
# 203 tag: XRef
# 204 tag: /XRef
# 204 tag: /Name
# 204 tag: Name
# 205 tag: ElementValue
#     206 data: Medullary thyroid cancer
# 206 tag: /ElementValue
# 206 tag: XRef
# 207 tag: /XRef
# 207 tag: /Name
# 207 tag: Symbol
# 208 tag: ElementValue
#     209 data: MTC
# 209 tag: /ElementValue
# 209 tag: XRef
# 210 tag: /XRef
# 210 tag: /Symbol
# 210 tag: Citation
# 211 tag: ID
#     212 data: 19469690
# 212 tag: /ID
# 212 tag: /Citation
# 212 tag: Citation
# 213 tag: ID
#     214 data: 24493721
# 214 tag: /ID
# 214 tag: /Citation
# 214 tag: Citation
# 215 tag: ID
#     216 data: 3419007
# 216 tag: /ID
# 216 tag: /Citation
# 216 tag: XRef
# 217 tag: /XRef
# 217 tag: XRef
# 218 tag: /XRef
# 218 tag: XRef
# 219 tag: /XRef
# 219 tag: XRef
# 220 tag: /XRef
# 220 tag: /Trait
# 220 tag: /TraitSet
# 220 tag: TraitSet
# 221 tag: Trait
# 222 tag: Name
# 223 tag: ElementValue
#     224 data: Neoplastic Syndromes, Hereditary
# 224 tag: /ElementValue
# 224 tag: XRef
# 225 tag: /XRef
# 225 tag: /Name
# 225 tag: Name
# 226 tag: ElementValue
#     227 data: Hereditary cancer-predisposing syndrome
# 227 tag: /ElementValue
# 227 tag: XRef
# 228 tag: /XRef
# 228 tag: /Name
# 228 tag: Name
# 229 tag: ElementValue
#     230 data: Tumor predisposition
# 230 tag: /ElementValue
# 230 tag: /Name
# 230 tag: Name
# 231 tag: ElementValue
#     232 data: Cancer predisposition
# 232 tag: /ElementValue
# 232 tag: XRef
# 233 tag: /XRef
# 233 tag: /Name
# 233 tag: AttributeSet
# 234 tag: Attribute
#     235 data: Neoplasm
# 235 tag: /Attribute
# 235 tag: /AttributeSet
# 235 tag: AttributeSet
# 236 tag: Attribute
#     237 data: Hereditary cancer syndrome
# 237 tag: /Attribute
# 237 tag: /AttributeSet
# 237 tag: Citation
# 238 tag: ID
#     239 data: 3075918
# 239 tag: /ID
# 239 tag: /Citation
# 239 tag: Citation
# 240 tag: ID
#     241 data: 25394175
# 241 tag: /ID
# 241 tag: /Citation
# 241 tag: XRef
# 242 tag: /XRef
# 242 tag: /Trait
# 242 tag: /TraitSet
# 242 tag: TraitSet
# 243 tag: Trait
# 244 tag: Name
# 245 tag: ElementValue
#     246 data: AllHighlyPenetrant
# 246 tag: /ElementValue
# 246 tag: /Name
# 246 tag: Name
# 247 tag: ElementValue
#     248 data: not specified
# 248 tag: /ElementValue
# 248 tag: /Name
# 248 tag: AttributeSet
# 249 tag: Attribute
#     250 data: The term 'not specified' was created for use in ClinVar so that submitters can convey the concept that a variant is benign, likely benign, or of uncertain significance for an unspecified set of disorders.  This usage was introduced in 2014 to replace AllHighlyPenetrant.
# 250 tag: /Attribute
# 250 tag: /AttributeSet
# 250 tag: XRef
# 251 tag: /XRef
# 251 tag: /Trait
# 251 tag: /TraitSet
# 251 tag: TraitSet
# 252 tag: Trait
# 253 tag: Name
# 254 tag: ElementValue
#     255 data: not provided
# 255 tag: /ElementValue
# 255 tag: XRef
# 256 tag: /XRef
# 256 tag: /Name
# 256 tag: AttributeSet
# 257 tag: Attribute
#     258 data: The term 'not provided' is registered in MedGen to support identification of submissions to ClinVar for which no condition was named when assessing the variant. 'not provided' differs from 'not specified', which is used when a variant is asserted to be benign, likely benign, or of uncertain significance for conditions that have not been specified.
# 258 tag: /Attribute
# 258 tag: /AttributeSet
# 258 tag: XRef
# 259 tag: /XRef
# 259 tag: /Trait
# 259 tag: /TraitSet
# 259 tag: TraitSet
# 260 tag: Trait
# 261 tag: Name
# 262 tag: ElementValue
#     263 data: Multiple endocrine neoplasia, type 2
# 263 tag: /ElementValue
# 263 tag: XRef
# 264 tag: /XRef
# 264 tag: XRef
# 265 tag: /XRef
# 265 tag: XRef
# 266 tag: /XRef
# 266 tag: /Name
# 266 tag: Symbol
# 267 tag: ElementValue
#     268 data: MEN2
# 268 tag: /ElementValue
# 268 tag: XRef
# 269 tag: /XRef
# 269 tag: /Symbol
# 269 tag: AttributeSet
# 270 tag: Attribute
#     271 data: gain of function
# 271 tag: /Attribute
# 271 tag: XRef
# 272 tag: /XRef
# 272 tag: XRef
# 273 tag: /XRef
# 273 tag: XRef
# 274 tag: /XRef
# 274 tag: XRef
# 275 tag: /XRef
# 275 tag: XRef
# 276 tag: /XRef
# 276 tag: XRef
# 277 tag: /XRef
# 277 tag: XRef
# 278 tag: /XRef
# 278 tag: XRef
# 279 tag: /XRef
# 279 tag: XRef
# 280 tag: /XRef
# 280 tag: XRef
# 281 tag: /XRef
# 281 tag: XRef
# 282 tag: /XRef
# 282 tag: XRef
# 283 tag: /XRef
# 283 tag: XRef
# 284 tag: /XRef
# 284 tag: XRef
# 285 tag: /XRef
# 285 tag: XRef
# 286 tag: /XRef
# 286 tag: XRef
# 287 tag: /XRef
# 287 tag: XRef
# 288 tag: /XRef
# 288 tag: XRef
# 289 tag: /XRef
# 289 tag: XRef
# 290 tag: /XRef
# 290 tag: XRef
# 291 tag: /XRef
# 291 tag: XRef
# 292 tag: /XRef
# 292 tag: XRef
# 293 tag: /XRef
# 293 tag: /AttributeSet
# 293 tag: AttributeSet
# 294 tag: Attribute
#     295 data: Multiple endocrine neoplasia type 2 (MEN 2) includes the following phenotypes: MEN 2A, FMTC (familial medullary thyroid carcinoma, which may be a variant of MEN 2A), and MEN 2B. All three phenotypes involve high risk for development of medullary carcinoma of the thyroid (MTC); MEN 2A and MEN 2B involve an increased risk for pheochromocytoma; MEN 2A involves an increased risk for parathyroid adenoma or hyperplasia. Additional features in MEN 2B include mucosal neuromas of the lips and tongue, distinctive facies with enlarged lips, ganglioneuromatosis of the gastrointestinal tract, and a marfanoid habitus. MTC typically occurs in early childhood in MEN 2B, early adulthood in MEN 2A, and middle age in FMTC.
# 295 tag: /Attribute
# 295 tag: XRef
# 296 tag: /XRef
# 296 tag: /AttributeSet
# 296 tag: Citation
# 297 tag: ID
#     298 data: 20301434
# 298 tag: /ID
# 298 tag: ID
#     299 data: NBK1257
# 299 tag: /ID
# 299 tag: /Citation
# 299 tag: Citation
# 300 tag: ID
#     301 data: 11739416
# 301 tag: /ID
# 301 tag: /Citation
# 301 tag: Citation
# 302 tag: ID
#     303 data: 15604628
# 303 tag: /ID
# 303 tag: /Citation
# 303 tag: XRef
# 304 tag: /XRef
# 304 tag: XRef
# 305 tag: /XRef
# 305 tag: /Trait
# 305 tag: /TraitSet
# 305 tag: TraitSet
# 306 tag: Trait
# 307 tag: Name
# 308 tag: ElementValue
#     309 data: MEA I
# 309 tag: /ElementValue
# 309 tag: XRef
# 310 tag: /XRef
# 310 tag: /Name
# 310 tag: Name
# 311 tag: ElementValue
#     312 data: MEN I
# 312 tag: /ElementValue
# 312 tag: XRef
# 313 tag: /XRef
# 313 tag: /Name
# 313 tag: Name
# 314 tag: ElementValue
#     315 data: Multiple endocrine neoplasia, type 1
# 315 tag: /ElementValue
# 315 tag: XRef
# 316 tag: /XRef
# 316 tag: XRef
# 317 tag: /XRef
# 317 tag: /Name
# 317 tag: Symbol
# 318 tag: ElementValue
#     319 data: MEN1
# 319 tag: /ElementValue
# 319 tag: XRef
# 320 tag: /XRef
# 320 tag: /Symbol
# 320 tag: AttributeSet
# 321 tag: Attribute
#     322 data: Multiple endocrine neoplasia type 1 (MEN1) syndrome includes varying combinations of more than 20 endocrine and non-endocrine tumors. Endocrine tumors become evident either by overproduction of hormones by the tumor or by growth of the tumor itself. Parathyroid tumors are the main MEN1-associated endocrinopathy; onset in 90% of individuals is between ages 20 and 25 years with hypercalcemia evident by age 50 years; hypercalcemia causes lethargy, depression, confusion, anorexia, constipation, nausea, vomiting, diuresis, dehydration, hypercalciuria, kidney stones, increased bone resorption/fracture risk, hypertension, and shortened QT interval. Pituitary tumors include prolactinoma (the most common), which manifests as oligomenorrhea/amenorrhea and galactorrhea in females and sexual dysfunction in males. Well-differentiated endocrine tumors of the gastro-entero-pancreatic (GEP) tract can manifest as Zollinger-Ellison syndrome (gastrinoma); hypoglycemia (insulinoma); hyperglycemia, anorexia, glossitis, anemia, diarrhea, venous thrombosis, and skin rash (glucagonoma); and watery diarrhea, hypokalemia, and achlorhydria syndrome (vasoactive intestinal peptide [VIP]-secreting tumor). Carcinoid tumors are non-hormone-secreting and can manifest as a large mass after age 50 years. Adrenocortical tumors can be associated with primary hypercortisolism or hyperaldosteronism. Non-endocrine tumors include facial angiofibromas, collagenomas, lipomas, meningiomas, ependymomas, and leiomyomas.
# 322 tag: /Attribute
# 322 tag: XRef
# 323 tag: /XRef
# 323 tag: /AttributeSet
# 323 tag: AttributeSet
# 324 tag: Attribute
#     325 data: Neoplasm
# 325 tag: /Attribute
# 325 tag: /AttributeSet
# 325 tag: AttributeSet
# 326 tag: Attribute
#     327 data: Hereditary cancer syndrome
# 327 tag: /Attribute
# 327 tag: /AttributeSet
# 327 tag: Citation
# 328 tag: ID
#     329 data: 20301710
# 329 tag: /ID
# 329 tag: ID
#     330 data: NBK1538
# 330 tag: /ID
# 330 tag: /Citation
# 330 tag: Citation
# 331 tag: ID
#     332 data: 20065170
# 332 tag: /ID
# 332 tag: /Citation
# 332 tag: Citation
# 333 tag: ID
#     334 data: 11739416
# 334 tag: /ID
# 334 tag: /Citation
# 334 tag: Citation
# 335 tag: ID
#     336 data: 15604628
# 336 tag: /ID
# 336 tag: /Citation
# 336 tag: Citation
# 337 tag: ID
#     338 data: 23788249
# 338 tag: /ID
# 338 tag: /Citation
# 338 tag: Citation
# 339 tag: ID
#     340 data: 22723327
# 340 tag: /ID
# 340 tag: /Citation
# 340 tag: Citation
# 341 tag: ID
#     342 data: 25394175
# 342 tag: /ID
# 342 tag: /Citation
# 342 tag: Citation
# 343 tag: ID
#     344 data: 25356965
# 344 tag: /ID
# 344 tag: /Citation
# 344 tag: Citation
# 345 tag: ID
#     346 data: 27854360
# 346 tag: /ID
# 346 tag: ID
#     347 data: 10.1038/gim.2016.190
# 347 tag: /ID
# 347 tag: /Citation
# 347 tag: XRef
# 348 tag: /XRef
# 348 tag: XRef
# 349 tag: /XRef
# 349 tag: XRef
# 350 tag: /XRef
# 350 tag: XRef
# 351 tag: /XRef
# 351 tag: /Trait
# 351 tag: /TraitSet
# 351 tag: TraitSet
# 352 tag: Trait
# 353 tag: Name
# 354 tag: ElementValue
#     355 data: Multiple endocrine neoplasia, type 2b
# 355 tag: /ElementValue
# 355 tag: XRef
# 356 tag: /XRef
# 356 tag: XRef
# 357 tag: /XRef
# 357 tag: /Name
# 357 tag: Name
# 358 tag: ElementValue
#     359 data: Multiple endocrine neoplasia, type 3
# 359 tag: /ElementValue
# 359 tag: XRef
# 360 tag: /XRef
# 360 tag: /Name
# 360 tag: Name
# 361 tag: ElementValue
#     362 data: MULTIPLE ENDOCRINE NEOPLASIA, TYPE III
# 362 tag: /ElementValue
# 362 tag: XRef
# 363 tag: /XRef
# 363 tag: /Name
# 363 tag: Name
# 364 tag: ElementValue
#     365 data: MULTIPLE ENDOCRINE NEOPLASIA, TYPE IIB
# 365 tag: /ElementValue
# 365 tag: XRef
# 366 tag: /XRef
# 366 tag: XRef
# 367 tag: /XRef
# 367 tag: XRef
# 368 tag: /XRef
# 368 tag: /Name
# 368 tag: Name
# 369 tag: ElementValue
#     370 data: MEN IIB
# 370 tag: /ElementValue
# 370 tag: XRef
# 371 tag: /XRef
# 371 tag: /Name
# 371 tag: Name
# 372 tag: ElementValue
#     373 data: NEUROMATA, MUCOSAL, WITH ENDOCRINE TUMORS
# 373 tag: /ElementValue
# 373 tag: XRef
# 374 tag: /XRef
# 374 tag: /Name
# 374 tag: Symbol
# 375 tag: ElementValue
#     376 data: MEN2B
# 376 tag: /ElementValue
# 376 tag: XRef
# 377 tag: /XRef
# 377 tag: /Symbol
# 377 tag: Symbol
# 378 tag: ElementValue
#     379 data: MEN3
# 379 tag: /ElementValue
# 379 tag: XRef
# 380 tag: /XRef
# 380 tag: /Symbol
# 380 tag: Symbol
# 381 tag: ElementValue
#     382 data: RET
# 382 tag: /ElementValue
# 382 tag: /Symbol
# 382 tag: AttributeSet
# 383 tag: Attribute
#     384 data: Multiple endocrine neoplasia type 2 (MEN 2) includes the following phenotypes: MEN 2A, FMTC (familial medullary thyroid carcinoma, which may be a variant of MEN 2A), and MEN 2B. All three phenotypes involve high risk for development of medullary carcinoma of the thyroid (MT
#     384 data: C); MEN 2A and MEN 2B involve an increased risk for pheochromocytoma; MEN 2A involves an increased risk for parathyroid adenoma or hyperplasia. Additional features in MEN 2B include mucosal neuromas of the lips and tongue, distinctive facies with enlarged lips, ganglioneuromatosis of the gastrointestinal tract, and a marfanoid habitus. MTC typically occurs in early childhood in MEN 2B, early adulthood in MEN 2A, and middle age in FMTC.
# 384 tag: /Attribute
# 384 tag: XRef
# 385 tag: /XRef
# 385 tag: /AttributeSet
# 385 tag: AttributeSet
# 386 tag: Attribute
#     387 data: Neoplasm
# 387 tag: /Attribute
# 387 tag: /AttributeSet
# 387 tag: AttributeSet
# 388 tag: Attribute
#     389 data: Hereditary cancer syndrome
# 389 tag: /Attribute
# 389 tag: /AttributeSet
# 389 tag: Citation
# 390 tag: ID
#     391 data: 20301434
# 391 tag: /ID
# 391 tag: ID
#     392 data: NBK1257
# 392 tag: /ID
# 392 tag: /Citation
# 392 tag: Citation
# 393 tag: ID
#     394 data: 11739416
# 394 tag: /ID
# 394 tag: /Citation
# 394 tag: Citation
# 395 tag: ID
#     396 data: 19469690
# 396 tag: /ID
# 396 tag: /Citation
# 396 tag: Citation
# 397 tag: ID
#     398 data: 21863057
# 398 tag: /ID
# 398 tag: /Citation
# 398 tag: Citation
# 399 tag: ID
#     400 data: 8918855
# 400 tag: /ID
# 400 tag: /Citation
# 400 tag: Citation
# 401 tag: ID
#     402 data: 23788249
# 402 tag: /ID
# 402 tag: /Citation
# 402 tag: Citation
# 403 tag: ID
#     404 data: 24893135
# 404 tag: /ID
# 404 tag: /Citation
# 404 tag: Citation
# 405 tag: ID
#     406 data: 3419007
# 406 tag: /ID
# 406 tag: /Citation
# 406 tag: Citation
# 407 tag: ID
#     408 data: 25356965
# 408 tag: /ID
# 408 tag: /Citation
# 408 tag: Citation
# 409 tag: ID
#     410 data: 27854360
# 410 tag: /ID
# 410 tag: ID
#     411 data: 10.1038/gim.2016.190
# 411 tag: /ID
# 411 tag: /Citation
# 411 tag: XRef
# 412 tag: /XRef
# 412 tag: XRef
# 413 tag: /XRef
# 413 tag: XRef
# 414 tag: /XRef
# 414 tag: XRef
# 415 tag: /XRef
# 415 tag: XRef
# 416 tag: /XRef
# 416 tag: /Trait
# 416 tag: /TraitSet
# 416 tag: TraitSet
# 417 tag: Trait
# 418 tag: Name
# 419 tag: ElementValue
#     420 data: Multiple endocrine neoplasia, type 2a
# 420 tag: /ElementValue
# 420 tag: XRef
# 421 tag: /XRef
# 421 tag: XRef
# 422 tag: /XRef
# 422 tag: /Name
# 422 tag: Name
# 423 tag: ElementValue
#     424 data: MULTIPLE ENDOCRINE NEOPLASIA, TYPE IIA
# 424 tag: /ElementValue
# 424 tag: XRef
# 425 tag: /XRef
# 425 tag: XRef
# 426 tag: /XRef
# 426 tag: XRef
# 427 tag: /XRef
# 427 tag: XRef
# 428 tag: /XRef
# 428 tag: XRef
# 429 tag: /XRef
# 429 tag: XRef
# 430 tag: /XRef
# 430 tag: XRef
# 431 tag: /XRef
# 431 tag: XRef
# 432 tag: /XRef
# 432 tag: XRef
# 433 tag: /XRef
# 433 tag: XRef
# 434 tag: /XRef
# 434 tag: XRef
# 435 tag: /XRef
# 435 tag: XRef
# 436 tag: /XRef
# 436 tag: XRef
# 437 tag: /XRef
# 437 tag: XRef
# 438 tag: /XRef
# 438 tag: XRef
# 439 tag: /XRef
# 439 tag: XRef
# 440 tag: /XRef
# 440 tag: XRef
# 441 tag: /XRef
# 441 tag: XRef
# 442 tag: /XRef
# 442 tag: XRef
# 443 tag: /XRef
# 443 tag: /Name
# 443 tag: Symbol
# 444 tag: ElementValue
#     445 data: RET
# 445 tag: /ElementValue
# 445 tag: /Symbol
# 445 tag: Symbol
# 446 tag: ElementValue
#     447 data: MEN2A
# 447 tag: /ElementValue
# 447 tag: XRef
# 448 tag: /XRef
# 448 tag: /Symbol
# 448 tag: AttributeSet
# 449 tag: Attribute
#     450 data: Multiple endocrine neoplasia type 2 (MEN 2) includes the following phenotypes: MEN 2A, FMTC (familial medullary thyroid carcinoma, which may be a variant of MEN 2A), and MEN 2B. All three phenotypes involve high risk for development of medullary carcinoma of the thyroid (MTC); MEN 2A and MEN 2B involve an increased risk for pheochromocytoma; MEN 2A involves an increased risk for parathyroid adenoma or hyperplasia. Additional features in MEN 2B include mucosal neuromas of the lips and tongue, distinctive facies with enlarged lips, ganglioneuromatosis of the gastrointestinal tract, and a marfanoid habitus. MTC typically occurs in early childhood in MEN 2B, early adulthood in MEN 2A, and middle age in FMTC.
# 450 tag: /Attribute
# 450 tag: XRef
# 451 tag: /XRef
# 451 tag: /AttributeSet
# 451 tag: AttributeSet
# 452 tag: Attribute
#     453 data: Neoplasm
# 453 tag: /Attribute
# 453 tag: /AttributeSet
# 453 tag: AttributeSet
# 454 tag: Attribute
#     455 data: Hereditary cancer syndrome
# 455 tag: /Attribute
# 455 tag: /AttributeSet
# 455 tag: Citation
# 456 tag: ID
#     457 data: 20301434
# 457 tag: /ID
# 457 tag: ID
#     458 data: NBK1257
# 458 tag: /ID
# 458 tag: /Citation
# 458 tag: Citation
# 459 tag: ID
#     460 data: 11739416
# 460 tag: /ID
# 460 tag: /Citation
# 460 tag: Citation
# 461 tag: ID
#     462 data: 19469690
# 462 tag: /ID
# 462 tag: /Citation
# 462 tag: Citation
# 463 tag: ID
#     464 data: 21863057
# 464 tag: /ID
# 464 tag: /Citation
# 464 tag: Citation
# 465 tag: ID
#     466 data: 8918855
# 466 tag: /ID
# 466 tag: /Citation
# 466 tag: Citation
# 467 tag: ID
#     468 data: 23788249
# 468 tag: /ID
# 468 tag: /Citation
# 468 tag: Citation
# 469 tag: ID
#     470 data: 24893135
# 470 tag: /ID
# 470 tag: /Citation
# 470 tag: Citation
# 471 tag: ID
#     472 data: 3419007
# 472 tag: /ID
# 472 tag: /Citation
# 472 tag: Citation
# 473 tag: ID
#     474 data: 25394175
# 474 tag: /ID
# 474 tag: /Citation
# 474 tag: Citation
# 475 tag: ID
#     476 data: 25356965
# 476 tag: /ID
# 476 tag: /Citation
# 476 tag: Citation
# 477 tag: ID
#     478 data: 27854360
# 478 tag: /ID
# 478 tag: ID
#     479 data: 10.1038/gim.2016.190
# 479 tag: /ID
# 479 tag: /Citation
# 479 tag: XRef
# 480 tag: /XRef
# 480 tag: XRef
# 481 tag: /XRef
# 481 tag: XRef
# 482 tag: /XRef
# 482 tag: XRef
# 483 tag: /XRef
# 483 tag: XRef
# 484 tag: /XRef
# 484 tag: /Trait
# 484 tag: /TraitSet
# 484 tag: TraitSet
# 485 tag: Trait
# 486 tag: Name
# 487 tag: ElementValue
#     488 data: MULTIPLE ENDOCRINE NEOPLASIA, TYPE IV
# 488 tag: /ElementValue
# 488 tag: XRef
# 489 tag: /XRef
# 489 tag: XRef
# 490 tag: /XRef
# 490 tag: XRef
# 491 tag: /XRef
# 491 tag: XRef
# 492 tag: /XRef
# 492 tag: XRef
# 493 tag: /XRef
# 493 tag: XRef
# 494 tag: /XRef
# 494 tag: XRef
# 495 tag: /XRef
# 495 tag: /Name
# 495 tag: Name
# 496 tag: ElementValue
#     497 data: Multiple endocrine neoplasia, type 4
# 497 tag: /ElementValue
# 497 tag: XRef
# 498 tag: /XRef
# 498 tag: /Name
# 498 tag: Symbol
# 499 tag: ElementValue
#     500 data: MEN4
# 500 tag: /ElementValue
# 500 tag: XRef
# 501 tag: /XRef
# 501 tag: /Symbol
# 501 tag: AttributeSet
# 502 tag: Attribute
#     503 data: Multiple endocrine neoplasia is a group of disorders that affect the body's network of hormone-producing glands called the endocrine system. Hormones are chemical messengers that travel through the bloodstream and regulate the function of cells and tissues throughout the body. Multiple endocrine neoplasia typically involves tumors (neoplasia) in at least two endocrine glands; tumors can also develop in other organs and tissues. These growths can be noncancerous (benign) or cancerous (malignant). If the tumors become cancerous, the condition can be life-threatening.The major forms of multiple endocrine neoplasia are called type 1, type 2, and type 4. These types are distinguished by the genes involved, the types of hormones made, and the characteristic signs and symptoms.Many different types of tumors are associated with multiple endocrine neoplasia. Type 1 frequently involves tumors of the parathyroid glands, the pituitary gland, and the pancreas. Tumors in these glands can lead to the overproduction of hormones. The most common sign of multiple endocrine neoplasia type 1 is overactivity of the parathyroid glands (hyperparathyroidism). Hyperparathyroidism disrupts the normal balance of calcium in the blood, which can lead to kidney stones, thinning of bones, nausea and vomiting, high blood pressure (hypertension), weakness, and fatigue.The most common sign of multiple endocrine neoplasia type 2 is a form of thyroid cancer called medullary thyroid carcinoma. Some people with this disorder also develop a pheochromocytoma, which is an adrenal gland tumor that can cause dangerously high blood pressure. Multiple endocrine neoplasia type 2 is divided into three subtypes: type 2A, type 2B (formerly called type 3), and familial medullary thyroid carcinoma (FMTC). These subtypes differ in their characteristic signs and symptoms and risk of specific tumors; for example, hyperparathyroidism occurs only in type 2A, and medullary thyroid carcinoma is the only feature of FMTC. The signs and symptoms of multiple endocrine neoplasia type 2 are relativ
#     503 data: ely consistent within any one family.Multiple endocrine neoplasia type 4 appears to have signs and symptoms similar to those of type 1, although it is caused by mutations in a different gene. Hyperparathyroidism is the most common feature, followed by tumors of the pituitary gland, additional endocrine glands, and other organs.
# 503 tag: /Attribute
# 503 tag: XRef
# 504 tag: /XRef
# 504 tag: /AttributeSet
# 504 tag: AttributeSet
# 505 tag: Attribute
#     506 data: Neoplasm
# 506 tag: /Attribute
# 506 tag: /AttributeSet
# 506 tag: AttributeSet
# 507 tag: Attribute
#     508 data: Hereditary cancer syndrome
# 508 tag: /Attribute
# 508 tag: /AttributeSet
# 508 tag: XRef
# 509 tag: /XRef
# 509 tag: XRef
# 510 tag: /XRef
# 510 tag: /Trait
# 510 tag: /TraitSet
# 510 tag: TraitSet
# 511 tag: Trait
# 512 tag: Name
# 513 tag: ElementValue
#     514 data: Pheochromocytoma
# 514 tag: /ElementValue
# 514 tag: XRef
# 515 tag: /XRef
# 515 tag: XRef
# 516 tag: /XRef
# 516 tag: XRef
# 517 tag: /XRef
# 517 tag: /Name
# 517 tag: Name
# 518 tag: ElementValue
#     519 data: Pheochromocytoma, somatic
# 519 tag: /ElementValue
# 519 tag: /Name
# 519 tag: Name
# 520 tag: ElementValue
#     521 data: MAX-Related Hereditary Paraganglioma-Pheochromocytoma Syndrome
# 521 tag: /ElementValue
# 521 tag: /Name
# 521 tag: Name
# 522 tag: ElementValue
#     523 data: Chromaffin tumors
# 523 tag: /ElementValue
# 523 tag: XRef
# 524 tag: /XRef
# 524 tag: /Name
# 524 tag: AttributeSet
# 525 tag: Attribute
#     526 data: Hereditary paraganglioma-pheochromocytoma (PGL/PCC) syndromes are characterized by paragangliomas (tumors that arise from neuroendocrine tissues distributed along the paravertebral axis from the base of the skull to the pelvis) and pheochromocytomas (paragangliomas that are confined to the adrenal medulla). Sympathetic paragangliomas cause catecholamine excess; parasympathetic paragangliomas are most often nonsecretory. Extra-adrenal parasympathetic paragangliomas are located predominantly in the skull base and neck (referred to as head and neck PGL [HNPGL]) and sometimes in the upper mediastinum; approximately 95% of such tumors are nonsecretory. In contrast, sympathetic extra-adrenal paragangliomas are generally confined to the lower mediastinum, abdomen, and pelvis, and are typically secretory. Pheochromocytomas, which arise from the adrenal medulla, typically lead to catecholamine excess. Symptoms of PGL/PCC result from either mass effects or catecholamine hypersecretion (e.g., sustained or paroxysmal elevations in blood pressure, headache, episodic profuse sweating, forceful palpitations, pallor, and apprehension or anxiety). The risk for developing metastatic disease is greater for extra-adrenal sympathetic paragangliomas than for pheochromocytomas.
# 526 tag: /Attribute
# 526 tag: XRef
# 527 tag: /XRef
# 527 tag: /AttributeSet
# 527 tag: AttributeSet
# 528 tag: Attribute
#     529 data: Neoplasm
# 529 tag: /Attribute
# 529 tag: /AttributeSet
# 529 tag: AttributeSet
# 530 tag: Attribute
#     531 data: Hereditary cancer syndrome
# 531 tag: /Attribute
# 531 tag: /AttributeSet
# 531 tag: Citation
# 532 tag: ID
#     533 data: 20301715
# 533 tag: /ID
# 533 tag: ID
#     534 data: NBK1548
# 534 tag: /ID
# 534 tag: /Citation
# 534 tag: Citation
# 535 tag: ID
#     536 data: 24893135
# 536 tag: /ID
# 536 tag: /Citation
# 536 tag: Citation
# 537 tag: ID
#     538 data: 24493721
# 538 tag: /ID
# 538 tag: /Citation
# 538 tag: Citation
# 539 tag: ID
#     540 data: 3419007
# 540 tag: /ID
# 540 tag: /Citation
# 540 tag: Citation
# 541 tag: ID
#     542 data: 24319509
# 542 tag: /ID
# 542 tag: /Citation
# 542 tag: XRef
# 543 tag: /XRef
# 543 tag: XRef
# 544 tag: /XRef
# 544 tag: XRef
# 545 tag: /XRef
# 545 tag: XRef
# 546 tag: /XRef
# 546 tag: /Trait
# 546 tag: /TraitSet
# 546 tag: /ConditionList
# 546 tag: /Interpretation
# 546 tag: /Interpretations
# 546 tag: XRefList
# 547 tag: XRef
# 548 tag: /XRef
# 548 tag: XRef
# 549 tag: /XRef
# 549 tag: XRef
# 550 tag: /XRef
# 550 tag: XRef
# 551 tag: /XRef
# 551 tag: XRef
# 552 tag: /XRef
# 552 tag: XRef
# 553 tag: /XRef
# 553 tag: XRef
# 554 tag: /XRef
# 554 tag: XRef
# 555 tag: /XRef
# 555 tag: XRef
# 556 tag: /XRef
# 556 tag: /XRefList
# 556 tag: /SimpleAllele
# 556 tag: Haplotype
# 557 tag: SimpleAllele
# 558 tag: GeneList
# 559 tag: Gene
# 560 tag: Location
# 561 tag: CytogeneticLocation
#     562 data: 10q11.21
# 562 tag: /CytogeneticLocation
# 562 tag: SequenceLocation
# 563 tag: /SequenceLocation
# 563 tag: SequenceLocation
# 564 tag: /SequenceLocation
# 564 tag: /Location
# 564 tag: OMIM
#     565 data: 164761
# 565 tag: /OMIM
# 565 tag: Haploinsufficiency
#     566 data: Sufficient evidence for dosage pathogenicity
# 566 tag: /Haploinsufficiency
# 566 tag: Triplosensitivity
#     567 data: No evidence available
# 567 tag: /Triplosensitivity
# 567 tag: Property
#     568 data: gene_acmg_incidental_2013
# 568 tag: /Property
# 568 tag: /Gene
# 568 tag: /GeneList
# 568 tag: Name
#     569 data: NM_020975.6(RET):c.2944C
#     569 data: >
#     569 data: T (p.Arg982Cys)
# 569 tag: /Name
# 569 tag: CanonicalSPDI
#     570 data: NC_000010.11:43124886:C:T
# 570 tag: /CanonicalSPDI
# 570 tag: VariantType
#     571 data: single nucleotide variant
# 571 tag: /VariantType
# 571 tag: Location
# 572 tag: CytogeneticLocation
#     573 data: 10q11.21
# 573 tag: /CytogeneticLocation
# 573 tag: SequenceLocation
# 574 tag: /SequenceLocation
# 574 tag: SequenceLocation
# 575 tag: /SequenceLocation
# 575 tag: /Location
# 575 tag: OtherNameList
# 576 tag: Name
#     577 data: p.R982C:CGC
#     577 data: >
#     577 data: TGC
# 577 tag: /Name
# 577 tag: /OtherNameList
# 577 tag: ProteinChange
#     578 data: R982C
# 578 tag: /ProteinChange
# 578 tag: ProteinChange
#     579 data: R728C
# 579 tag: /ProteinChange
# 579 tag: HGVSlist
# 580 tag: HGVS
# 581 tag: NucleotideExpression
# 582 tag: Expression
#     583 data: NC_000010.10:g.43620335C
#     583 data: >
#     583 data: T
# 583 tag: /Expression
# 583 tag: /NucleotideExpression
# 583 tag: /HGVS
# 583 tag: HGVS
# 584 tag: NucleotideExpression
# 585 tag: Expression
#     586 data: NC_000010.11:g.43124887C
#     586 data: >
#     586 data: T
# 586 tag: /Expression
# 586 tag: /NucleotideExpression
# 586 tag: /HGVS
# 586 tag: HGVS
# 587 tag: NucleotideExpression
# 588 tag: Expression
#     589 data: NM_001355216.1:c.2182C
#     589 data: >
#     589 data: T
# 589 tag: /Expression
# 589 tag: /NucleotideExpression
# 589 tag: ProteinExpression
# 590 tag: Expression
#     591 data: NP_001342145.1:p.Arg728Cys
# 591 tag: /Expression
# 591 tag: /ProteinExpression
# 591 tag: MolecularConsequence
# 592 tag: /MolecularConsequence
# 592 tag: /HGVS
# 592 tag: HGVS
# 593 tag: NucleotideExpression
# 594 tag: Expression
#     595 data: NM_020630.5:c.2944C
#     595 data: >
#     595 data: T
# 595 tag: /Expression
# 595 tag: /NucleotideExpression
# 595 tag: ProteinExpression
# 596 tag: Expression
#     597 data: NP_065681.1:p.Arg982Cys
# 597 tag: /Expression
# 597 tag: /ProteinExpression
# 597 tag: MolecularConsequence
# 598 tag: /MolecularConsequence
# 598 tag: /HGVS
# 598 tag: HGVS
# 599 tag: NucleotideExpression
# 600 tag: Expression
#     601 data: NM_020975.6:c.2944C
#     601 data: >
#     601 data: T
# 601 tag: /Expression
# 601 tag: /NucleotideExpression
# 601 tag: ProteinExpression
# 602 tag: Expression
#     603 data: NP_066124.1:p.Arg982Cys
# 603 tag: /Expression
# 603 tag: /ProteinExpression
# 603 tag: MolecularConsequence
# 604 tag: /MolecularConsequence
# 604 tag: /HGVS
# 604 tag: HGVS
# 605 tag: NucleotideExpression
# 606 tag: Expression
#     607 data: LRG_518t1:c.2944C
#     607 data: >
#     607 data: T
# 607 tag: /Expression
# 607 tag: /NucleotideExpression
# 607 tag: /HGVS
# 607 tag: HGVS
# 608 tag: NucleotideExpression
# 609 tag: Expression
#     610 data: LRG_518t2:c.2944C
#     610 data: >
#     610 data: T
# 610 tag: /Expression
# 610 tag: /NucleotideExpression
# 610 tag: /HGVS
# 610 tag: HGVS
# 611 tag: NucleotideExpression
# 612 tag: Expression
#     613 data: LRG_518t1:c.2944C
#     613 data: >
#     613 data: T
# 613 tag: /Expression
# 613 tag: /NucleotideExpression
# 613 tag: ProteinExpression
# 614 tag: Expression
#     615 data: LRG_518p1:p.Arg982Cys
# 615 tag: /Expression
# 615 tag: /ProteinExpression
# 615 tag: /HGVS
# 615 tag: HGVS
# 616 tag: NucleotideExpression
# 617 tag: Expression
#     618 data: LRG_518:g.52819C
#     618 data: >
#     618 data: T
# 618 tag: /Expression
# 618 tag: /NucleotideExpression
# 618 tag: /HGVS
# 618 tag: HGVS
# 619 tag: NucleotideExpression
# 620 tag: Expression
#     621 data: NG_007489.1:g.52819C
#     621 data: >
#     621 data: T
# 621 tag: /Expression
# 621 tag: /NucleotideExpression
# 621 tag: /HGVS
# 621 tag: HGVS
# 622 tag: ProteinExpression
# 623 tag: Expression
#     624 data: NP_066124.1:p.Arg982Cys
# 624 tag: /Expression
# 624 tag: /ProteinExpression
# 624 tag: /HGVS
# 624 tag: HGVS
# 625 tag: ProteinExpression
# 626 tag: Expression
#     627 data: P07949:p.Arg982Cys
# 627 tag: /Expression
# 627 tag: /ProteinExpression
# 627 tag: /HGVS
# 627 tag: /HGVSlist
# 627 tag: Interpretations
# 628 tag: Interpretation
# 629 tag: Description
#     630 data: Conflicting interpretations of pathogenicity
# 630 tag: /Description
# 630 tag: Explanation
#     631 data: Benign(12);Likely benign(4);Uncertain significance(1)
# 631 tag: /Explanation
# 631 tag: Citation
# 632 tag: ID
#     633 data: 21655256
# 633 tag: /ID
# 633 tag: /Citation
# 633 tag: Citation
# 634 tag: ID
#     635 data: 7881414
# 635 tag: /ID
# 635 tag: /Citation
# 635 tag: Citation
# 636 tag: ID
#     637 data: 23084198
# 637 tag: /ID
# 637 tag: /Citation
# 637 tag: Citation
# 638 tag: ID
#     639 data: 22703879
# 639 tag: /ID
# 639 tag: /Citation
# 639 tag: Citation
# 640 tag: ID
#     641 data: 23527089
# 641 tag: /ID
# 641 tag: /Citation
# 641 tag: Citation
# 642 tag: ID
#     643 data: 27153395
# 643 tag: /ID
# 643 tag: /Citation
# 643 tag: Citation
# 644 tag: ID
#     645 data: 22729463
# 645 tag: /ID
# 645 tag: /Citation
# 645 tag: Citation
# 646 tag: ID
#     647 data: 16928683
# 647 tag: /ID
# 647 tag: /Citation
# 647 tag: Citation
# 648 tag: URL
#     649 data: http://www.egl-eurofins.com/emvclass/emvclass.php?approved_symbol=RET
# 649 tag: /URL
# 649 tag: /Citation
# 649 tag: Citation
# 650 tag: ID
#     651 data: 14566559
# 651 tag: /ID
# 651 tag: /Citation
# 651 tag: Citation
# 652 tag: ID
#     653 data: 15741265
# 653 tag: /ID
# 653 tag: /Citation
# 653 tag: Citation
# 654 tag: ID
#     655 data: 10646792
# 655 tag: /ID
# 655 tag: /Citation
# 655 tag: Citation
# 656 tag: ID
#     657 data: 9727738
# 657 tag: /ID
# 657 tag: /Citation
# 657 tag: Citation
# 658 tag: ID
#     659 data: 12566528
# 659 tag: /ID
# 659 tag: /Citation
# 659 tag: Citation
# 660 tag: ID
#     661 data: 22837065
# 661 tag: /ID
# 661 tag: /Citation
# 661 tag: Citation
# 662 tag: ID
#     663 data: 14633923
# 663 tag: /ID
# 663 tag: /Citation
# 663 tag: Citation
# 664 tag: ID
#     665 data: 22995991
# 665 tag: /ID
# 665 tag: /Citation
# 665 tag: Citation
# 666 tag: ID
#     667 data: 16441254
# 667 tag: /ID
# 667 tag: /Citation
# 667 tag: Citation
# 668 tag: ID
#     669 data: 27884173
# 669 tag: /ID
# 669 tag: /Citation
# 669 tag: Citation
# 670 tag: ID
#     671 data: 20981092
# 671 tag: /ID
# 671 tag: /Citation
# 671 tag: Citation
# 672 tag: ID
#     673 data: 24728327
# 673 tag: /ID
# 673 tag: /Citation
# 673 tag: Citation
# 674 tag: ID
#     675 data: 7647787
# 675 tag: /ID
# 675 tag: /Citation
# 675 tag: Citation
# 676 tag: ID
#     677 data: 21995290
# 677 tag: /ID
# 677 tag: /Citation
# 677 tag: Citation
# 678 tag: ID
#     679 data: 9760196
# 679 tag: /ID
# 679 tag: /Citation
# 679 tag: Comment
#     680 data: Benign(12);Likely benign(4);Uncertain significance(1)
# 680 tag: /Comment
# 680 tag: DescriptionHistory
# 681 tag: Description
#     682 data: Conflicting interpretations of pathogenicity, risk factor
# 682 tag: /Description
# 682 tag: /DescriptionHistory
# 682 tag: DescriptionHistory
# 683 tag: Description
#     684 data: Benign/Likely benign, risk factor
# 684 tag: /Description
# 684 tag: /DescriptionHistory
# 684 tag: DescriptionHistory
# 685 tag: Description
#     686 data: Benign/Likely benign, not provided, risk factor
# 686 tag: /Description
# 686 tag: /DescriptionHistory
# 686 tag: ConditionList
# 687 tag: TraitSet
# 688 tag: Trait
# 689 tag: Name
# 690 tag: ElementValue
#     691 data: Hirschsprung Disease, Dominant
# 691 tag: /ElementValue
# 691 tag: XRef
# 692 tag: /XRef
# 692 tag: /Name
# 692 tag: XRef
# 693 tag: /XRef
# 693 tag: /Trait
# 693 tag: /TraitSet
# 693 tag: TraitSet
# 694 tag: Trait
# 695 tag: Name
# 696 tag: ElementValue
#     697 data: Multiple endocrine neoplasia
# 697 tag: /ElementValue
# 697 tag: XRef
# 698 tag: /XRef
# 698 tag: XRef
# 699 tag: /XRef
# 699 tag: /Name
# 699 tag: XRef
# 700 tag: /XRef
# 700 tag: XRef
# 701 tag: /XRef
# 701 tag: XRef
# 702 tag: /XRef
# 702 tag: /Trait
# 702 tag: /TraitSet
# 702 tag: TraitSet
# 703 tag: Trait
# 704 tag: Name
# 705 tag: ElementValue
#     706 data: Neoplastic Syndromes, Hereditary
# 706 tag: /ElementValue
# 706 tag: XRef
# 707 tag: /XRef
# 707 tag: /Name
# 707 tag: Name
# 708 tag: ElementValue
#     709 data: Hereditary cancer-predisposing syndrome
# 709 tag: /ElementValue
# 709 tag: XRef
# 710 tag: /XRef
# 710 tag: /Name
# 710 tag: Name
# 711 tag: ElementValue
#     712 data: Tumor predisposition
# 712 tag: /ElementValue
# 712 tag: /Name
# 712 tag: Name
# 713 tag: ElementValue
#     714 data: Cancer predisposition
# 714 tag: /ElementValue
# 714 tag: XRef
# 715 tag: /XRef
# 715 tag: /Name
# 715 tag: AttributeSet
# 716 tag: Attribute
#     717 data: Neoplasm
# 717 tag: /Attribute
# 717 tag: /AttributeSet
# 717 tag: AttributeSet
# 718 tag: Attribute
#     719 data: Hereditary cancer syndrome
# 719 tag: /Attribute
# 719 tag: /AttributeSet
# 719 tag: Citation
# 720 tag: ID
#     721 data: 3075918
# 721 tag: /ID
# 721 tag: /Citation
# 721 tag: Citation
# 722 tag: ID
#     723 data: 25394175
# 723 tag: /ID
# 723 tag: /Citation
# 723 tag: XRef
# 724 tag: /XRef
# 724 tag: /Trait
# 724 tag: /TraitSet
# 724 tag: TraitSet
# 725 tag: Trait
# 726 tag: Name
# 727 tag: ElementValue
#     728 data: AllHighlyPenetrant
# 728 tag: /ElementValue
# 728 tag: /Name
# 728 tag: Name
# 729 tag: ElementValue
#     730 data: not specified
# 730 tag: /ElementValue
# 730 tag: /Name
# 730 tag: AttributeSet
# 731 tag: Attribute
#     732 data: The term 'not specified' was created for use in ClinVar so that submitters can convey the concept that a variant is benign, likely benign, or of uncertain significance for an unspecified set of disorders.  This usage was introduced in 2014 to replace AllHighlyPenetrant.
# 732 tag: /Attribute
# 732 tag: /AttributeSet
# 732 tag: XRef
# 733 tag: /XRef
# 733 tag: /Trait
# 733 tag: /TraitSet
# 733 tag: TraitSet
# 734 tag: Trait
# 735 tag: Name
# 736 tag: ElementValue
#     737 data: not provided
# 737 tag: /ElementValue
# 737 tag: XRef
# 738 tag: /XRef
# 738 tag: /Name
# 738 tag: AttributeSet
# 739 tag: Attribute
#     740 data: The term 'not provided' is registered in MedGen to support identification of submissions to ClinVar for which no condition was named when assessing the variant. 'not provided' differs from 'not specified', which is used when a variant is asserted to be benign, likely benign, or of uncertain significance for conditions that have not been specified.
# 740 tag: /Attribute
# 740 tag: /AttributeSet
# 740 tag: XRef
# 741 tag: /XRef
# 741 tag: /Trait
# 741 tag: /TraitSet
# 741 tag: TraitSet
# 742 tag: Trait
# 743 tag: Name
# 744 tag: ElementValue
#     745 data: Hirschsprung's disease
# 745 tag: /ElementValue
# 745 tag: XRef
# 746 tag: /XRef
# 746 tag: /Name
# 746 tag: Name
# 747 tag: ElementValue
#     748 data: Hirschsprung disease
# 748 tag: /ElementValue
# 748 tag: XRef
# 749 tag: /XRef
# 749 tag: XRef
# 750 tag: /XRef
# 750 tag: XRef
# 751 tag: /XRef
# 751 tag: XRef
# 752 tag: /XRef
# 752 tag: XRef
# 753 tag: /XRef
# 753 tag: /Name
# 753 tag: Symbol
# 754 tag: ElementValue
#     755 data: HSCR
# 755 tag: /ElementValue
# 755 tag: XRef
# 756 tag: /XRef
# 756 tag: XRef
# 757 tag: /XRef
# 757 tag: /Symbol
# 757 tag: AttributeSet
# 758 tag: Attribute
#     759 data: Hirschsprung disease (HSCR), or congenital intestinal aganglionosis, is a birth defect characterized by complete absence of neuronal ganglion cells from a portion of the intestinal tract. The aganglionic segment includes the distal rectum and a variable length of contiguous proximal intestine. In 80% of individuals, aganglionosis is restricted to the rectosigmoid colon (short-segment disease); in 15%-20%, aganglionosis extends proximal to the sigmoid colon (long-segment disease); in about 5%, aganglionosis affects the entire large intestine (total colonic aganglionosis). Rarely, the aganglionosis extends into the small bowel or even more proximally to encompass the entire bowel (total intestinal aganglionosis). HSCR is considered a neurocristopathy, a disorder of cells and tissues derived from the neural crest, and may occur as an isolated finding or as part of a multisystem disorder. Affected infants frequently present in the first two months of life with symptoms of impaired intestinal motility such as failure to pass meconium within the first 48 hours of life, constipation, emesis, abdominal pain or distention, and occasionally diarrhea. However, because the initial diagnosis of HSCR may be delayed until late childhood or adulthood, HSCR should be considered in anyone with lifelong severe constipation. Individuals with H
#     759 data: SCR are at risk for enterocolitis and/or potentially lethal intestinal perforation.
# 759 tag: /Attribute
# 759 tag: XRef
# 760 tag: /XRef
# 760 tag: /AttributeSet
# 760 tag: Citation
# 761 tag: ID
#     762 data: 20301612
# 762 tag: /ID
# 762 tag: ID
#     763 data: NBK1439
# 763 tag: /ID
# 763 tag: /Citation
# 763 tag: XRef
# 764 tag: /XRef
# 764 tag: XRef
# 765 tag: /XRef
# 765 tag: XRef
# 766 tag: /XRef
# 766 tag: XRef
# 767 tag: /XRef
# 767 tag: /Trait
# 767 tag: /TraitSet
# 767 tag: TraitSet
# 768 tag: Trait
# 769 tag: Name
# 770 tag: ElementValue
#     771 data: Multiple endocrine neoplasia, type 2b
# 771 tag: /ElementValue
# 771 tag: XRef
# 772 tag: /XRef
# 772 tag: XRef
# 773 tag: /XRef
# 773 tag: /Name
# 773 tag: Name
# 774 tag: ElementValue
#     775 data: Multiple endocrine neoplasia, type 3
# 775 tag: /ElementValue
# 775 tag: XRef
# 776 tag: /XRef
# 776 tag: /Name
# 776 tag: Name
# 777 tag: ElementValue
#     778 data: MULTIPLE ENDOCRINE NEOPLASIA, TYPE III
# 778 tag: /ElementValue
# 778 tag: XRef
# 779 tag: /XRef
# 779 tag: /Name
# 779 tag: Name
# 780 tag: ElementValue
#     781 data: MULTIPLE ENDOCRINE NEOPLASIA, TYPE IIB
# 781 tag: /ElementValue
# 781 tag: XRef
# 782 tag: /XRef
# 782 tag: XRef
# 783 tag: /XRef
# 783 tag: XRef
# 784 tag: /XRef
# 784 tag: /Name
# 784 tag: Name
# 785 tag: ElementValue
#     786 data: MEN IIB
# 786 tag: /ElementValue
# 786 tag: XRef
# 787 tag: /XRef
# 787 tag: /Name
# 787 tag: Name
# 788 tag: ElementValue
#     789 data: NEUROMATA, MUCOSAL, WITH ENDOCRINE TUMORS
# 789 tag: /ElementValue
# 789 tag: XRef
# 790 tag: /XRef
# 790 tag: /Name
# 790 tag: Symbol
# 791 tag: ElementValue
#     792 data: MEN2B
# 792 tag: /ElementValue
# 792 tag: XRef
# 793 tag: /XRef
# 793 tag: /Symbol
# 793 tag: Symbol
# 794 tag: ElementValue
#     795 data: MEN3
# 795 tag: /ElementValue
# 795 tag: XRef
# 796 tag: /XRef
# 796 tag: /Symbol
# 796 tag: Symbol
# 797 tag: ElementValue
#     798 data: RET
# 798 tag: /ElementValue
# 798 tag: /Symbol
# 798 tag: AttributeSet
# 799 tag: Attribute
# ...
# 1518 tag: XRef
# 1519 tag: /XRef
# 1519 tag: XRef
# 1520 tag: /XRef
# 1520 tag: XRef
# 1521 tag: /XRef
# 1521 tag: /Name
# 1521 tag: Name
# 1522 tag: ElementValue
#     1523 data: Pheochromocytoma, somatic
# 1523 tag: /ElementValue
# 1523 tag: /Name
# 1523 tag: Name
# 1524 tag: ElementValue
#     1525 data: MAX-Related Hereditary Paraganglioma-Pheochromocytoma Syndrome
# 1525 tag: /ElementValue
# 1525 tag: /Name
# 1525 tag: Name
# 1526 tag: ElementValue
#     1527 data: Chromaffin tumors
# 1527 tag: /ElementValue
# 1527 tag: XRef
# 1528 tag: /XRef
# 1528 tag: /Name
# 1528 tag: AttributeSet
# 1529 tag: Attribute
#     1530 data: Hereditary paraganglioma-pheochromocytoma (PGL/PCC) syndromes are characterized by paragangliomas (tumors that arise from neuroendocrine tissues distributed along the paravertebral axis from the base of the skull to the pelvis) and pheochromocytomas (paragangliomas that are confined to the adrenal medulla). Sympathetic paragangliomas cause catecholamine excess; parasympathetic paragangliomas are most often nonsecretory. Extra-adrenal parasympathetic paragangliomas are located predominantly in the skull base and neck (referred to as head and neck PGL [HNPGL]) and sometimes in the upper mediastinum; approximately 95% of such tumors are nonsecretory. In contrast, sympathetic extra-adrenal paragangliomas are generally confined to the lower mediastinum, abdomen, and pelvis, and are typically secretory. Pheochromocytomas, which arise from the adrenal medulla, typically lead to catecholamine excess. Symptoms of PGL/PCC result from either mass effects or catecholamine hypersecretion (e.g., sustained or paroxysmal elevations in blood pressure, headache, episodic profuse sweating, forceful palpitations, pallor, and apprehension or anxiety). The risk for developing metastatic disease is greater for extra-adrenal sympathetic paragangliomas than for pheochromocytomas.
# 1530 tag: /Attribute
# 1530 tag: XRef
# 1531 tag: /XRef
# 1531 tag: /AttributeSet
# 1531 tag: AttributeSet
# 1532 tag: Attribute
#     1533 data: Neoplasm
# 1533 tag: /Attribute
# 1533 tag: /AttributeSet
# 1533 tag: AttributeSet
# 1534 tag: Attribute
#     1535 data: Hereditary cancer syndrome
# 1535 tag: /Attribute
# 1535 tag: /AttributeSet
# 1535 tag: Citation
# 1536 tag: ID
#     1537 data: 20301715
# 1537 tag: /ID
# 1537 tag: ID
#     1538 data: NBK1548
# 1538 tag: /ID
# 1538 tag: /Citation
# 1538 tag: Citation
# 1539 tag: ID
#     1540 data: 24893135
# 1540 tag: /ID
# 1540 tag: /Citation
# 1540 tag: Citation
# 1541 tag: ID
#     1542 data: 24493721
# 1542 tag: /ID
# 1542 tag: /Citation
# 1542 tag: Citation
# 1543 tag: ID
#     1544 data: 3419007
# 1544 tag: /ID
# 1544 tag: /Citation
# 1544 tag: Citation
# 1545 tag: ID
#     1546 data: 24319509
# 1546 tag: /ID
# 1546 tag: /Citation
# 1546 tag: XRef
# 1547 tag: /XRef
# 1547 tag: XRef
# 1548 tag: /XRef
# 1548 tag: XRef
# 1549 tag: /XRef
# 1549 tag: XRef
# 1550 tag: /XRef
# 1550 tag: /Trait
# 1550 tag: /TraitSet
# 1550 tag: TraitSet
# 1551 tag: Trait
# 1552 tag: Name
# 1553 tag: ElementValue
#     1554 data: Renal hypodysplasia/aplasia 1
# 1554 tag: /ElementValue
# 1554 tag: /Name
# 1554 tag: Symbol
# 1555 tag: ElementValue
#     1556 data: BRA
# 1556 tag: /ElementValue
# 1556 tag: XRef
# 1557 tag: /XRef
# 1557 tag: /Symbol
# 1557 tag: Symbol
# 1558 tag: ElementValue
#     1559 data: RHDA1
# 1559 tag: /ElementValue
# 1559 tag: XRef
# 1560 tag: /XRef
# 1560 tag: /Symbol
# 1560 tag: XRef
# 1561 tag: /XRef
# 1561 tag: XRef
# 1562 tag: /XRef
# 1562 tag: XRef
# 1563 tag: /XRef
# 1563 tag: /Trait
# 1563 tag: /TraitSet
# 1563 tag: /ConditionList
# 1563 tag: /Interpretation
# 1563 tag: /Interpretations
# 1563 tag: XRefList
# 1564 tag: XRef
# 1565 tag: /XRef
# 1565 tag: XRef
# 1566 tag: /XRef
# 1566 tag: XRef
# 1567 tag: /XRef
# 1567 tag: XRef
# 1568 tag: /XRef
# 1568 tag: XRef
# 1569 tag: /XRef
# 1569 tag: /XRefList
# 1569 tag: AlleleFrequencyList
# 1570 tag: AlleleFrequency
# 1571 tag: /AlleleFrequency
# 1571 tag: AlleleFrequency
# 1572 tag: /AlleleFrequency
# 1572 tag: AlleleFrequency
# 1573 tag: /AlleleFrequency
# 1573 tag: AlleleFrequency
# 1574 tag: /AlleleFrequency
# 1574 tag: /AlleleFrequencyList
# 1574 tag: GlobalMinorAlleleFrequency
# 1575 tag: /GlobalMinorAlleleFrequency
# 1575 tag: /SimpleAllele
# 1575 tag: Name
#     1576 data: NM_020975.4(RET):c.[200G
#     1576 data: >
#     1576 data: A;874G
#     1576 data: >
#     1576 data: A;2944C
#     1576 data: >
#     1576 data: T]
# 1576 tag: /Name
# 1576 tag: VariationType
#     1577 data: Haplotype
# 1577 tag: /VariationType
# 1577 tag: HGVSlist
# 1578 tag: HGVS
# 1579 tag: NucleotideExpression
# 1580 tag: Expression
#     1581 data: NM_020975.4:c.[200G
#     1581 data: >
#     1581 data: A;874G
#     1581 data: >
#     1581 data: A;2944C
#     1581 data: >
#     1581 data: T]
# 1581 tag: /Expression
# 1581 tag: /NucleotideExpression
# 1581 tag: /HGVS
# 1581 tag: /HGVSlist
# 1581 tag: Interpretations
# 1582 tag: Interpretation
# 1583 tag: Description
#     1584 data: Uncertain significance
# 1584 tag: /Description
# 1584 tag: Citation
# 1585 tag: ID
#     1586 data: 21655256
# 1586 tag: /ID
# 1586 tag: /Citation
# 1586 tag: DescriptionHistory
# 1587 tag: Description
#     1588 data: Pathogenic
# 1588 tag: /Description
# 1588 tag: /DescriptionHistory
# 1588 tag: ConditionList
# 1589 tag: TraitSet
# 1590 tag: Trait
# 1591 tag: Name
# 1592 tag: ElementValue
#     1593 data: Multiple endocrine neoplasia, type 2
# 1593 tag: /ElementValue
# 1593 tag: XRef
# 1594 tag: /XRef
# 1594 tag: XRef
# 1595 tag: /XRef
# 1595 tag: XRef
# 1596 tag: /XRef
# 1596 tag: /Name
# 1596 tag: Symbol
# 1597 tag: ElementValue
#     1598 data: MEN2
# 1598 tag: /ElementValue
# 1598 tag: XRef
# 1599 tag: /XRef
# 1599 tag: /Symbol
# 1599 tag: AttributeSet
# 1600 tag: Attribute
#     1601 data: Multiple endocrine neoplasia type 2 (MEN 2) includes the following phenotypes: MEN 2A, FMTC (familial medullary thyroid carcinoma, which may be a variant of MEN 2A), and MEN 2B. All three phenotypes involve high risk for development of medullary carcinoma of the thyroid (MTC); MEN 2A and MEN 2B involve an increased risk for pheochromocytoma; MEN 2A involves an increased risk for parathyroid adenoma or hyperplasia. Additional features in MEN 2B include mucosal neuromas of the lips and tongue, distinctive facies with enlarged lips, ganglioneuromatosis of the gastrointestinal tract, and a marfanoid habitus. MTC typically occurs in early childhood in MEN 2B, early adulthood in MEN 2A, and middle age in FMTC.
# 1601 tag: /Attribute
# 1601 tag: XRef
# 1602 tag: /XRef
# 1602 tag: /AttributeSet
# 1602 tag: AttributeSet
# 1603 tag: Attribute
#     1604 data: gain of function
# 1604 tag: /Attribute
# 1604 tag: XRef
# 1605 tag: /XRef
# 1605 tag: XRef
# 1606 tag: /XRef
# 1606 tag: XRef
# 1607 tag: /XRef
# 1607 tag: XRef
# 1608 tag: /XRef
# 1608 tag: XRef
# 1609 tag: /XRef
# 1609 tag: XRef
# 1610 tag: /XRef
# 1610 tag: XRef
# 1611 tag: /XRef
# 1611 tag: XRef
# 1612 tag: /XRef
# 1612 tag: XRef
# 1613 tag: /XRef
# 1613 tag: XRef
# 1614 tag: /XRef
# 1614 tag: XRef
# 1615 tag: /XRef
# 1615 tag: XRef
# 1616 tag: /XRef
# 1616 tag: XRef
# 1617 tag: /XRef
# 1617 tag: XRef
# 1618 tag: /XRef
# 1618 tag: XRef
# 1619 tag: /XRef
# 1619 tag: XRef
# 1620 tag: /XRef
# 1620 tag: XRef
# 1621 tag: /XRef
# 1621 tag: XRef
# 1622 tag: /XRef
# 1622 tag: XRef
# 1623 tag: /XRef
# 1623 tag: XRef
# 1624 tag: /XRef
# 1624 tag: XRef
# 1625 tag: /XRef
# 1625 tag: XRef
# 1626 tag: /XRef
# 1626 tag: /AttributeSet
# 1626 tag: Citation
# 1627 tag: ID
#     1628 data: 20301434
# 1628 tag: /ID
# 1628 tag: ID
#     1629 data: NBK1257
# 1629 tag: /ID
# 1629 tag: /Citation
# 1629 tag: Citation
# 1630 tag: ID
#     1631 data: 11739416
# 1631 tag: /ID
# 1631 tag: /Citation
# 1631 tag: Citation
# 1632 tag: ID
#     1633 data: 15604628
# 1633 tag: /ID
# 1633 tag: /Citation
# 1633 tag: XRef
# 1634 tag: /XRef
# 1634 tag: XRef
# 1635 tag: /XRef
# 1635 tag: /Trait
# 1635 tag: /TraitSet
# 1635 tag: /ConditionList
# 1635 tag: /Interpretation
# 1635 tag: /Interpretations
# 1635 tag: XRefList
# 1636 tag: XRef
# 1637 tag: /XRef
# 1637 tag: /XRefList
# 1637 tag: /Haplotype
# 1637 tag: Name
#     1638 data: NM_020975.4:c.[1901G
#     1638 data: >
#     1638 data: A];[200G
#     1638 data: >
#     1638 data: A;874G
#     1638 data: >
#     1638 data: A;2944C
#     1638 data: >
#     1638 data: T]
# 1638 tag: /Name
# 1638 tag: VariationType
#     1639 data: CompoundHeterozygote
# 1639 tag: /VariationType
# 1639 tag: HGVSlist
# 1640 tag: HGVS
# 1641 tag: NucleotideExpression
# 1642 tag: Expression
#     1643 data: NM_020630.5:c.[1901G
#     1643 data: >
#     1643 data: A];[200G
#     1643 data: >
#     1643 data: A[2944C
#     1643 data: >
#     1643 data: T[874G
#     1643 data: >
#     1643 data: A]
# 1643 tag: /Expression
# 1643 tag: /NucleotideExpression
# 1643 tag: /HGVS
# 1643 tag: /HGVSlist
# 1643 tag: /Genotype
# 1643 tag: ReviewStatus
#     1644 data: no assertion criteria provided
# 1644 tag: /ReviewStatus
# 1644 tag: RCVList
# 1645 tag: RCVAccession
# 1646 tag: InterpretedConditionList
# 1647 tag: InterpretedCondition
#     1648 data: Multiple endocrine neoplasia, type 2
# 1648 tag: /InterpretedCondition
# 1648 tag: /InterpretedConditionList
# 1648 tag: /RCVAccession
# 1648 tag: /RCVList
# 1648 tag: Interpretations
# 1649 tag: Interpretation
# 1650 tag: Description
#     1651 data: Pathogenic
# 1651 tag: /Description
# 1651 tag: Citation
# 1652 tag: ID
#     1653 data: 21655256
# 1653 tag: /ID
# 1653 tag: /Citation
# 1653 tag: ConditionList
# 1654 tag: TraitSet
# 1655 tag: Trait
# 1656 tag: Name
# 1657 tag: ElementValue
#     1658 data: Multiple endocrine neoplasia, type 2
# 1658 tag: /ElementValue
# 1658 tag: XRef
# 1659 tag: /XRef
# 1659 tag: XRef
# 1660 tag: /XRef
# 1660 tag: XRef
# 1661 tag: /XRef
# 1661 tag: /Name
# 1661 tag: Symbol
# 1662 tag: ElementValue
#     1663 data: MEN2
# 1663 tag: /ElementValue
# 1663 tag: XRef
# 1664 tag: /XRef
# 1664 tag: /Symbol
# 1664 tag: AttributeSet
# 1665 tag: Attribute
#     1666 data: Multiple endocrine neoplasia type 2 (MEN 2) includes the following phenotypes: MEN 2A, FMTC (familial medullary thyroid carcinoma, which may be a variant of MEN 2A), and MEN 2B. All three phenotypes involve high risk for development of medullary carcinoma of the thyroid (MTC); MEN 2A and MEN 2B involve an increased risk for pheochromocytoma; MEN 2A involves an increased risk for parathyroid adenoma or hyperplasia. Additional features in MEN 2B include mucosal neuromas of the lips and tongue, distinctive facies with enlarged lips, ganglioneuromatosis of the gastrointestinal tract, and a marfanoid habitus. MTC typically occurs in early childhood in MEN 2B, early adulthood in MEN 2A, and middle age in FMTC.
# 1666 tag: /Attribute
# 1666 tag: XRef
# 1667 tag: /XRef
# 1667 tag: /AttributeSet
# 1667 tag: AttributeSet
# 1668 tag: Attribute
#     1669 data: gain of function
# 1669 tag: /Attribute
# 1669 tag: XRef
# 1670 tag: /XRef
# 1670 tag: XRef
# 1671 tag: /XRef
# 1671 tag: XRef
# 1672 tag: /XRef
# 1672 tag: XRef
# 1673 tag: /XRef
# 1673 tag: XRef
# 1674 tag: /XRef
# 1674 tag: XRef
# 1675 tag: /XRef
# 1675 tag: XRef
# 1676 tag: /XRef
# 1676 tag: XRef
# 1677 tag: /XRef
# 1677 tag: XRef
# 1678 tag: /XRef
# 1678 tag: XRef
# 1679 tag: /XRef
# 1679 tag: XRef
# 1680 tag: /XRef
# 1680 tag: XRef
# 1681 tag: /XRef
# 1681 tag: XRef
# 1682 tag: /XRef
# 1682 tag: XRef
# 1683 tag: /XRef
# 1683 tag: XRef
# 1684 tag: /XRef
# 1684 tag: XRef
# 1685 tag: /XRef
# 1685 tag: XRef
# 1686 tag: /XRef
# 1686 tag: XRef
# 1687 tag: /XRef
# 1687 tag: XRef
# 1688 tag: /XRef
# 1688 tag: XRef
# 1689 tag: /XRef
# 1689 tag: XRef
# 1690 tag: /XRef
# 1690 tag: XRef
# 1691 tag: /XRef
# 1691 tag: /AttributeSet
# 1691 tag: Citation
# 1692 tag: ID
#     1693 data: 20301434
# 1693 tag: /ID
# 1693 tag: ID
#     1694 data: NBK1257
# 1694 tag: /ID
# 1694 tag: /Citation
# 1694 tag: Citation
# 1695 tag: ID
#     1696 data: 11739416
# 1696 tag: /ID
# 1696 tag: /Citation
# 1696 tag: Citation
# 1697 tag: ID
#     1698 data: 15604628
# 1698 tag: /ID
# 1698 tag: /Citation
# 1698 tag: XRef
# 1699 tag: /XRef
# 1699 tag: XRef
# 1700 tag: /XRef
# 1700 tag: /Trait
# 1700 tag: /TraitSet
# 1700 tag: /ConditionList
# 1700 tag: /Interpretation
# 1700 tag: /Interpretations
# 1700 tag: ClinicalAssertionList
# 1701 tag: ClinicalAssertion
# 1702 tag: ClinVarSubmissionID
# 1703 tag: /ClinVarSubmissionID
# 1703 tag: ClinVarAccession
# 1704 tag: /ClinVarAccession
# 1704 tag: RecordStatus
#     1705 data: current
# 1705 tag: /RecordStatus
# 1705 tag: ReviewStatus
#     1706 data: no assertion criteria provided
# 1706 tag: /ReviewStatus
# 1706 tag: Interpretation
# 1707 tag: Description
#     1708 data: Pathogenic
# 1708 tag: /Description
# 1708 tag: Citation
# 1709 tag: ID
#     1710 data: 21655256
# 1710 tag: /ID
# 1710 tag: /Citation
# 1710 tag: Citation
# 1711 tag: URL
#     1712 data: http://www.arup.utah.edu/database/MEN2/MEN2_display.php
# 1712 tag: /URL
# 1712 tag: /Citation
# 1712 tag: Comment
#     1713 data: The p.V292M/R67H/R982C allele was found in trans with p.C634Y in a Chinese family, genotype c.[1901G
#     1713 data: >
#     1713 data: A];[200G
#     1713 data: >
#     1713 data: A;874G
#     1713 data: >
#     1713 data: A;2944C
#     1713 data: >
#     1713 data: T]. One family member had both variant RET alleles and MTC onset at 13 yrs. Family members with only the p.C634Y mutation had MEN2A. Family members with the p.V292M/R67H/R982C allele had MTC (70 yr) and C-cell hyperplasia (44 yr). Variants p.R67H and p.R982C are common and likely benign, GnomAD frequency 0.1% and 2%, respectively (gnomad.broadinstitute.org/gene/ENSG00000165731). For reports of p.V292M alone, see c.874G
#     1713 data: >
#     1713 data: A.
# 1713 tag: /Comment
# 1713 tag: /Interpretation
# 1713 tag: Assertion
#     1714 data: variation to disease
# 1714 tag: /Assertion
# 1714 tag: ObservedInList
# 1715 tag: ObservedIn
# 1716 tag: Sample
# 1717 tag: Origin
#     1718 data: germline
# 1718 tag: /Origin
# 1718 tag: GeographicOrigin
#     1719 data: China
# 1719 tag: /GeographicOrigin
# 1719 tag: Species
#     1720 data: human
# 1720 tag: /Species
# 1720 tag: AffectedStatus
#     1721 data: yes
# 1721 tag: /AffectedStatus
# 1721 tag: FamilyData
# 1722 tag: /FamilyData
# 1722 tag: /Sample
# 1722 tag: Method
# 1723 tag: MethodType
#     1724 data: literature only
# 1724 tag: /MethodType
# 1724 tag: /Method
# 1724 tag: ObservedData
# 1725 tag: Attribute
#     1726 data: not provided
# 1726 tag: /Attribute
# 1726 tag: /ObservedData
# 1726 tag: /ObservedIn
# 1726 tag: /ObservedInList
# 1726 tag: Genotype
# 1727 tag: SimpleAllele
# 1728 tag: GeneList
# 1729 tag: Gene
# 1730 tag: /Gene
# 1730 tag: /GeneList
# 1730 tag: VariantType
#     1731 data: Variation
# 1731 tag: /VariantType
# 1731 tag: AttributeSet
# 1732 tag: Attribute
#     1733 data: NM_020975.4:c.1901G
#     1733 data: >
#     1733 data: A
# 1733 tag: /Attribute
# 1733 tag: /AttributeSet
# 1733 tag: /SimpleAllele
# 1733 tag: Haplotype
# 1734 tag: SimpleAllele
# 1735 tag: GeneList
# 1736 tag: Gene
# 1737 tag: /Gene
# 1737 tag: /GeneList
# 1737 tag: VariantType
#     1738 data: Variation
# 1738 tag: /VariantType
# 1738 tag: AttributeSet
# 1739 tag: Attribute
#     1740 data: NM_020975.4:c.200G
#     1740 data: >
#     1740 data: A
# 1740 tag: /Attribute
# 1740 tag: /AttributeSet
# 1740 tag: /SimpleAllele
# 1740 tag: SimpleAllele
# 1741 tag: GeneList
# 1742 tag: Gene
# 1743 tag: /Gene
# 1743 tag: /GeneList
# 1743 tag: VariantType
#     1744 data: Variation
# 1744 tag: /VariantType
# 1744 tag: AttributeSet
# 1745 tag: Attribute
#     1746 data: NM_020975.4:c.874G
#     1746 data: >
#     1746 data: A
# 1746 tag: /Attribute
# 1746 tag: /AttributeSet
# 1746 tag: /SimpleAllele
# 1746 tag: SimpleAllele
# 1747 tag: GeneList
# 1748 tag: Gene
# 1749 tag: /Gene
# 1749 tag: /GeneList
# 1749 tag: VariantType
#     1750 data: Variation
# 1750 tag: /VariantType
# 1750 tag: AttributeSet
# 1751 tag: Attribute
#     1752 data: NM_020975.4:c.2944C
#     1752 data: >
#     1752 data: T
# 1752 tag: /Attribute
# 1752 tag: /AttributeSet
# 1752 tag: /SimpleAllele
# 1752 tag: /Haplotype
# 1752 tag: Name
#     1753 data: NM_020975.4:c.[1901G
#     1753 data: >
#     1753 data: A];[200G
#     1753 data: >
#     1753 data: A;874G
#     1753 data: >
#     1753 data: A;2944C
#     1753 data: >
#     1753 data: T]
# 1753 tag: /Name
# 1753 tag: VariationType
#     1754 data: CompoundHeterozygote
# 1754 tag: /VariationType
# 1754 tag: /Genotype
# 1754 tag: TraitSet
# 1755 tag: Trait
# 1756 tag: XRef
# 1757 tag: /XRef
# 1757 tag: /Trait
# 1757 tag: /TraitSet
# 1757 tag: SubmissionNameList
# 1758 tag: SubmissionName
#     1759 data: MEN2 update May 2018
# 1759 tag: /SubmissionName
# 1759 tag: /SubmissionNameList
# 1759 tag: /ClinicalAssertion
# 1759 tag: /ClinicalAssertionList
# 1759 tag: TraitMappingList
# 1760 tag: TraitMapping
# 1761 tag: MedGen
# 1762 tag: /MedGen
# 1762 tag: /TraitMapping
# 1762 tag: /TraitMappingList
# 1762 tag: /InterpretedRecord
# 1762 tag: /VariationArchive
# 680000
# debug: the xml file is closed
# Empty DataFrame
# Columns: []
# Index: []

# %%
tree = etree.parse('../data/clinvarVariation_7.xml')
root = tree.getroot()
node = tree.find('VariationArchive[@Accession="VCV000012722"]')
mydata = etree.tostring(node)
myfile = open('../data/subnode.xml', 'wb')
myfile.write(mydata)
# Out:
# 42977

# %%
# makes dictionary of fasta sequences and np number 
# returns the dictionary
def makeDictOfFasta(dictpath):
    fasta_dict = {}
    for root, d_names, file_names in os.walk(dictpath):
        for filename in file_names:
            fname = os.path.join(root, filename)
            with open(fname) as f:
                print('opened a fasta file')
                np_num = ''
                sequence = ''
                for line in f:
                    if line[0] == '>':
                        if sequence != '':
                            fasta_dict[np_num] = sequence
                            np_num = ''
                            sequence = ''                    
                        i = 1
                        while line[i] != ' ':
                            np_num += line[i]
                            i += 1
                    else:
                        line = line.strip('\n')
                        sequence += line
    print(f'length of fasta dictionary: {len(fasta_dict)}')
    return fasta_dict

# %%
df_0 = pd.read_csv('../data/MM_enzyme.csv')
df_0.head()
# Out:
#            interpretation   gene  \
# 0  uncertain significance  HOGA1
# 1  uncertain significance    AGA
# 2  uncertain significance   DPYD
# 3  uncertain significance    PTS
# 4  uncertain significance   PROC
#
#                                            gene_name     accession mutation  \
# 0                4-hydroxy-2-oxoglutarate aldolase 1  VCV000000031     R97C
# 1                            aspartylglucosaminidase  VCV000000222     G60D
# 2                    dihydropyrimidine dehydrogenase  VCV000000437    R886H
# 3                6-pyruvoyltetrahydropterin synthase  VCV000000477     R16C
# 4  protein C, inactivator of coagulation factors ...  VCV000000661    P210L
#
#             NP Chr      start       stop referenceAllele alternateAllele  \
# 0  NP_612422.2  10   97598852   97598852               C               T
# 1  NP_000018.2   4  177440375  177440375               C               T
# 2  NP_000101.2   1   97098598   97098598               C               T
# 3  NP_000308.1  11  112226489  112226489               C               T
# 4  NP_000303.1   2  127426178  127426178               C               T
#
#    FASTA  PDB
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 3    NaN  NaN
# 4    NaN  NaN

# %%
fasta_dict = makeDictOfFasta('../fasta_sequences/')
# Out:
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# opened a fasta file
# length of fasta dictionary: 113602

# %%
# crops fasta sequence
# returns the cropped sequnece with a specified range
def cropFASTA(sequence, location, reference, seqRange):
    if location - 1 < len(sequence) and sequence[location - 1] == reference:
        proteinSeq = sequence[0 if location - 1 - seqRange <= 0 else location - 1 - seqRange : location + seqRange]
        return proteinSeq
    else:
        return None

# %%
def addFASTAfromDict(fasta_dict, df):
    none_acc = []
    seq_list = []
    for index, row in df.iterrows():
        mutation = row['mutation']
        try:
            ref = mutation[0]
            location = int(mutation[1:len(mutation)-1])
            np_num = row['NP']  # specify the column of np 
            sequence = fasta_dict.get(np_num)
            seqRange = 10  # range of sequences to take
            seq = cropFASTA(sequence, location, ref, seqRange) if sequence else None
        except:
            seq = None
            accession = row['accession']
            none_acc.append(accession)
        seq_list.append(seq)
    df['FASTA'] = seq_list
    print(f'Unfound Sequences: {len(none_acc)} {none_acc}')
    return df

# %%
df_1 = addFASTAfromDict(fasta_dict, df_0)
df_1.head()
# Out:
# Unfound Sequences: 46 ['VCV000134028', 'VCV000134108', 'VCV000134670', 'VCV000288381', 'VCV000418418', 'VCV000474413', 'VCV000490097', 'VCV000503859', 'VCV000531064', 'VCV000541685', 'VCV000582159', 'VCV000583086', 'VCV000591262', 'VCV000591672', 'VCV000591831', 'VCV000594518', 'VCV000598475', 'VCV000524323', 'VCV000437115', 'VCV000418344', 'VCV000464734', 'VCV000566152', 'VCV000800863', 'VCV000133712', 'VCV000134623', 'VCV000537105', 'VCV000572650', 'VCV000625941', 'VCV000630885', 'VCV000650338', 'VCV000650666', 'VCV000658054', 'VCV000664737', 'VCV000240738', 'VCV000411042', 'VCV000412448', 'VCV000181879', 'VCV000053180', 'VCV000216871', 'VCV000428273', 'VCV000453687', 'VCV000462579', 'VCV000481269', 'VCV000484704', 'VCV000589537', 'VCV000827598']
#            interpretation   gene  \
# 0  uncertain significance  HOGA1
# 1  uncertain significance    AGA
# 2  uncertain significance   DPYD
# 3  uncertain significance    PTS
# 4  uncertain significance   PROC
#
#                                            gene_name     accession mutation  \
# 0                4-hydroxy-2-oxoglutarate aldolase 1  VCV000000031     R97C
# 1                            aspartylglucosaminidase  VCV000000222     G60D
# 2                    dihydropyrimidine dehydrogenase  VCV000000437    R886H
# 3                6-pyruvoyltetrahydropterin synthase  VCV000000477     R16C
# 4  protein C, inactivator of coagulation factors ...  VCV000000661    P210L
#
#             NP Chr      start       stop referenceAllele alternateAllele  \
# 0  NP_612422.2  10   97598852   97598852               C               T
# 1  NP_000018.2   4  177440375  177440375               C               T
# 2  NP_000101.2   1   97098598   97098598               C               T
# 3  NP_000308.1  11  112226489  112226489               C               T
# 4  NP_000303.1   2  127426178  127426178               C               T
#
#                    FASTA  PDB
# 0  SERLEVVSRVRQAMPKNRLLL  NaN
# 1  GGSALDAVESGCAMCEREQCD  NaN
# 2  LPSFGPYLEQRKKIIAENKIR  NaN
# 3  GGRRCQAQVSRRISFSASHRL  NaN
# 4  DTEDQEDQVDPRLIDGKMTRR  NaN

# %%
df_1[['NP', 'gene', 'gene_name', 'FASTA']].head()
# Out:
#             NP   gene                                          gene_name  \
# 0  NP_612422.2  HOGA1                4-hydroxy-2-oxoglutarate aldolase 1
# 1  NP_000018.2    AGA                            aspartylglucosaminidase
# 2  NP_000101.2   DPYD                    dihydropyrimidine dehydrogenase
# 3  NP_000308.1    PTS                6-pyruvoyltetrahydropterin synthase
# 4  NP_000303.1   PROC  protein C, inactivator of coagulation factors ...
#
#                    FASTA
# 0  SERLEVVSRVRQAMPKNRLLL
# 1  GGSALDAVESGCAMCEREQCD
# 2  LPSFGPYLEQRKKIIAENKIR
# 3  GGRRCQAQVSRRISFSASHRL
# 4  DTEDQEDQVDPRLIDGKMTRR

# %%
# make FASTA format text file from dataframe for blast search
def makeFASTAfile(df, output_path):
    subset = df[['NP', 'gene', 'gene_name', 'FASTA']]
    tuples = [tuple(x) for x in subset.values]
    with open(output_path, 'w') as f:
        for tup in tuples:
            line = '>' + '\t'.join(tup[0:3]) + '\n'
            fasta = str(tup[3]) + '\n'
            f.write(line)
            f.write(fasta)

# %%
makeFASTAfile(df_1, '../data/fasta.txt')

# %%
def blastLocal(fasta_path, out_path, evalue=10.0, window_size=3):
    cmd1 = '../ncbi/blast/bin/'
    cmd2 = 'blastp' + ' '\
         + '-query ' + fasta_path + ' '\
         + '-db ' + cmd1 + 'pdbaa' + ' '\
         + '-evalue ' + str(evalue) + ' '\
         + '-outfmt ' + '5' + ' '\
         + '-out ' + out_path
    cmd = cmd1 + cmd2
    b_cmd = os.system(cmd)
    print(cmd + ' : ran with exit code %d' %b_cmd)

# %%
fasta_path = '../data/fasta_10.txt'  # path for the fasta file
out_path = '../data/myOutput.xml'  # path for the output file
evalue = 10.0
size = 3
blastLocal(fasta_path, out_path, evalue, size)
# Out:
# ../ncbi/blast/bin/blastp -query ../data/fasta_10.txt -db ../ncbi/blast/bin/pdbaa -evalue 10.0 -outfmt 5 -out ../data/myOutput.xml : ran with exit code 0

# %%
class BlastHandler(object):
    def __init__:
        self.dictlist = {}
